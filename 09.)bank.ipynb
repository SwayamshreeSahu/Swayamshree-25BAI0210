# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/bank.csv")

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.head(7)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
# 5   42  management   single   tertiary      no        0     yes  yes  unknown
# 6   56  management  married   tertiary      no      830     yes  yes  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# ...

# %%
df.head(15)
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    59       admin.   married  secondary      no     2343     yes   no
# 1    56       admin.   married  secondary      no       45      no   no
# 2    41   technician   married  secondary      no     1270     yes   no
# 3    55     services   married  secondary      no     2476     yes   no
# 4    54       admin.   married   tertiary      no      184      no   no
# 5    42   management    single   tertiary      no        0     yes  yes
# 6    56   management   married   tertiary      no      830     yes  yes
# 7    60      retired  divorced  secondary      no      545     yes   no
# 8    37   technician   married  secondary      no        1     yes   no
# 9    28     services    single  secondary      no     5090     yes   no
# 10   38       admin.    single  secondary      no      100     yes   no
# 11   30  blue-collar   married  secondary      no      309     yes   no
# ...

# %%
df.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
df.tail(15)
# Out:
#        age           job  marital  education default  balance housing loan  \
# 11147   44    unemployed  married  secondary      no        0      no   no
# 11148   32   blue-collar  married  secondary      no        1     yes   no
# 11149   46  entrepreneur  married  secondary      no     3317      no   no
# 11150   34    management  married  secondary      no      355      no   no
# 11151   40    management  married   tertiary      no      917     yes   no
# 11152   34     housemaid  married  secondary      no      390     yes   no
# 11153   43        admin.   single  secondary      no       35      no   no
# 11154   52    technician  married   tertiary      no      523     yes  yes
# 11155   35   blue-collar  married  secondary      no       80     yes  yes
# 11156   34   blue-collar   single  secondary      no      -72     yes   no
# 11157   33   blue-collar   single    primary      no        1     yes   no
# ...

# %%
df.min(numeric_only=True)
# Out:
# age           18
# balance    -6847
# day            1
# duration       2
# campaign       1
# pdays         -1
# previous       0
# dtype: int64

# %%
df.max(numeric_only=True)
# Out:
# age            95
# balance     81204
# day            31
# duration     3881
# campaign       63
# pdays         854
# previous       58
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
df['previous'].dtypes
# Out:
# dtype('int64')

# %%
df['deposit'].dtypes
# Out:
# dtype('O')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=11162, step=1), Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 189754

# %%
print(df.shape)
# Out:
# (11162, 17)

# %%
print(df.values)
# Out:
# [[59 'admin.' 'married' ... 0 'unknown' 'yes']
#  [56 'admin.' 'married' ... 0 'unknown' 'yes']
#  [41 'technician' 'married' ... 0 'unknown' 'yes']
#  ...
#  [32 'technician' 'single' ... 0 'unknown' 'no']
#  [43 'technician' 'married' ... 5 'failure' 'no']
#  [34 'technician' 'married' ... 0 'unknown' 'no']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 11162

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 11162

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 189754

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df.median(numeric_only=True)
# Out:
# age          39.0
# balance     550.0
# day          15.0
# duration    255.0
# campaign      2.0
# pdays        -1.0
# previous      0.0
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    age  balance  day  duration  campaign  pdays  previous
# 0   31        0   20        97         1     -1         0

# %%
df.mean(numeric_only=True)
# Out:
# age           41.231948
# balance     1528.538524
# day           15.658036
# duration     371.993818
# campaign       2.508421
# pdays         51.330407
# previous       0.832557
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# age           11.913369
# balance     3225.413326
# day            8.420740
# duration     347.128386
# campaign       2.722077
# pdays        108.758282
# previous       2.292007
# dtype: float64

# %%
df.sample(5)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 9065   32  self-employed  married   tertiary      no     1214      no   no
# 44     52     management  married    unknown      no     2240     yes   no
# 9894   57        retired  married  secondary      no      519     yes   no
# 4145   47      housemaid  married  secondary      no     2524      no   no
# 3018   34     management  married   tertiary      no     2037      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 9065  cellular   11   aug       104         2     -1         0  unknown
# 44     unknown   13   may       845         1     -1         0  unknown
# 9894   unknown    3   jun       393         3     -1         0  unknown
# 4145  cellular   12   oct       105         1     -1         0  unknown
# 3018  cellular   15   dec       324         2     -1         0  unknown
#
#      deposit
# 9065      no
# 44       yes
# 9894      no
# 4145     yes
# ...

# %%
df.sample(20)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 9124    49    blue-collar   married    primary      no      247      no  yes
# 9717    38    blue-collar  divorced  secondary      no        0     yes   no
# 9125    32    blue-collar    single    primary      no      180     yes   no
# 11137   49        retired   married    unknown      no      247      no   no
# 7092    33     technician   married  secondary      no      -74     yes   no
# 4231    24        student    single    primary      no     1235      no   no
# 9577    40     technician    single  secondary      no      822     yes  yes
# 8865    38    blue-collar   married  secondary      no      -40     yes   no
# 8286    63  self-employed   married   tertiary      no      661      no   no
# 10829   30       services   married  secondary      no      292     yes  yes
# 10177   38     management    single   tertiary      no     8669     yes   no
# ...

# %%
df.dropna()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# age          41.08
# balance     807.46
# day           9.14
# duration    923.56
# campaign      1.86
# pdays        -1.00
# previous      0.00
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# age          40.56
# balance     437.46
# day          14.62
# duration    220.58
# campaign      2.56
# pdays        23.84
# previous      0.38
# dtype: float64

# %%
df['age']
# Out:
# 0        59
# 1        56
# 2        41
# 3        55
# 4        54
#          ..
# 11157    33
# 11158    39
# 11159    32
# 11160    43
# 11161    34
# Name: age, Length: 11162, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df['job'].describe()
# Out:
# count          11162
# unique            12
# top       management
# freq            2566
# Name: job, dtype: object

# %%
df['education'].count()
# Out:
# np.int64(11162)

# %%
df['duration'].count()
# Out:
# np.int64(11162)

# %%
df['day'].mean()
# Out:
# np.float64(15.658036194230425)

# %%
df['age'].mean()
# Out:
# np.float64(41.231947679627304)

# %%
df[10:30]
# Out:
#     age          job   marital  education default  balance housing loan  \
# 10   38       admin.    single  secondary      no      100     yes   no
# 11   30  blue-collar   married  secondary      no      309     yes   no
# 12   29   management   married   tertiary      no      199     yes  yes
# 13   46  blue-collar    single   tertiary      no      460     yes   no
# 14   31   technician    single   tertiary      no      703     yes   no
# 15   35   management  divorced   tertiary      no     3837     yes   no
# 16   32  blue-collar    single    primary      no      611     yes   no
# 17   49     services   married  secondary      no       -8     yes   no
# 18   41       admin.   married  secondary      no       55     yes   no
# 19   49       admin.  divorced  secondary      no      168     yes  yes
# 20   28       admin.  divorced  secondary      no      785     yes   no
# 21   43   management    single   tertiary      no     2067     yes   no
# ...

# %%
df[5:14]
# Out:
#     age          job   marital  education default  balance housing loan  \
# 5    42   management    single   tertiary      no        0     yes  yes
# 6    56   management   married   tertiary      no      830     yes  yes
# 7    60      retired  divorced  secondary      no      545     yes   no
# 8    37   technician   married  secondary      no        1     yes   no
# 9    28     services    single  secondary      no     5090     yes   no
# 10   38       admin.    single  secondary      no      100     yes   no
# 11   30  blue-collar   married  secondary      no      309     yes   no
# 12   29   management   married   tertiary      no      199     yes  yes
# 13   46  blue-collar    single   tertiary      no      460     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 5   unknown    5   may       562         2     -1         0  unknown     yes
# 6   unknown    6   may      1201         1     -1         0  unknown     yes
# ...

# %%
df.loc[10:20,['loan', 'contact', 'day']]
# Out:
#    loan  contact  day
# 10   no  unknown    7
# 11   no  unknown    7
# 12  yes  unknown    7
# 13   no  unknown    7
# 14   no  unknown    8
# 15   no  unknown    8
# 16   no  unknown    8
# 17   no  unknown    8
# 18   no  unknown    8
# 19  yes  unknown    8
# 20   no  unknown    8

# %%
df.loc[10:20,['previous', 'poutcome', 'deposit']]
# Out:
#     previous poutcome deposit
# 10         0  unknown     yes
# 11         0  unknown     yes
# 12         0  unknown     yes
# 13         0  unknown     yes
# 14         0  unknown     yes
# 15         0  unknown     yes
# 16         0  unknown     yes
# 17         0  unknown     yes
# 18         0  unknown     yes
# 19         0  unknown     yes
# 20         0  unknown     yes

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...
