# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/CASchools.csv")

# %%
df.head()
# Out:
#    rownames  district                           school   county grades  \
# 0         1     75119               Sunol Glen Unified  Alameda  KK-08
# 1         2     61499             Manzanita Elementary    Butte  KK-08
# 2         3     61549      Thermalito Union Elementary    Butte  KK-08
# 3         4     61457  Golden Feather Union Elementary    Butte  KK-08
# 4         5     61523         Palermo Union Elementary    Butte  KK-08
#
#    students   teachers   calworks      lunch  computer  expenditure  \
# 0       195  10.900000   0.510200   2.040800        67  6384.911133
# 1       240  11.150000  15.416700  47.916698       101  5099.380859
# 2      1550  82.900002  55.032299  76.322601       169  5501.954590
# 3       243  14.000000  36.475399  77.049202        85  7101.831055
# 4      1335  71.500000  33.108601  78.427002       171  5235.987793
#
#       income    english        read        math
# 0  22.690001   0.000000  691.599976  690.000000
# ...

# %%
df.head(10)
# Out:
#    rownames  district                           school       county grades  \
# 0         1     75119               Sunol Glen Unified      Alameda  KK-08
# 1         2     61499             Manzanita Elementary        Butte  KK-08
# 2         3     61549      Thermalito Union Elementary        Butte  KK-08
# 3         4     61457  Golden Feather Union Elementary        Butte  KK-08
# 4         5     61523         Palermo Union Elementary        Butte  KK-08
# 5         6     62042          Burrel Union Elementary       Fresno  KK-08
# 6         7     68536            Holt Union Elementary  San Joaquin  KK-08
# 7         8     63834              Vineland Elementary         Kern  KK-08
# 8         9     62331         Orange Center Elementary       Fresno  KK-08
# 9        10     67306      Del Paso Heights Elementary   Sacramento  KK-06
#
#    students    teachers   calworks       lunch  computer  expenditure  \
# 0       195   10.900000   0.510200    2.040800        67  6384.911133
# ...

# %%
df.head(20)
# Out:
#     rownames  district                           school       county grades  \
# 0          1     75119               Sunol Glen Unified      Alameda  KK-08
# 1          2     61499             Manzanita Elementary        Butte  KK-08
# 2          3     61549      Thermalito Union Elementary        Butte  KK-08
# 3          4     61457  Golden Feather Union Elementary        Butte  KK-08
# 4          5     61523         Palermo Union Elementary        Butte  KK-08
# 5          6     62042          Burrel Union Elementary       Fresno  KK-08
# 6          7     68536            Holt Union Elementary  San Joaquin  KK-08
# 7          8     63834              Vineland Elementary         Kern  KK-08
# 8          9     62331         Orange Center Elementary       Fresno  KK-08
# 9         10     67306      Del Paso Heights Elementary   Sacramento  KK-06
# 10        11     65722        Le Grand Union Elementary       Merced  KK-08
# ...

# %%
df.tail()
# Out:
#      rownames  district                  school       county grades  students  \
# 415       416     68957  Las Lomitas Elementary    San Mateo  KK-08       984
# 416       417     69518    Los Altos Elementary  Santa Clara  KK-08      3724
# 417       418     72611  Somis Union Elementary      Ventura  KK-08       441
# 418       419     72744       Plumas Elementary         Yuba  KK-08       101
# 419       420     72751    Wheatland Elementary         Yuba  KK-08      1778
#
#        teachers  calworks      lunch  computer  expenditure     income  \
# 415   59.730000    0.1016   3.556900       195  7290.338867  28.716999
# 416  208.479996    1.0741   1.503800       721  5741.462891  41.734108
# 417   20.150000    3.5635  37.193802        45  4402.831543  23.733000
# 418    5.000000   11.8812  59.405899        14  4776.336426   9.952000
# 419   93.400002    6.9235  47.571201       313  5993.392578  12.502000
#
#        english        read        math
# ...

# %%
df.tail(6)
# Out:
#      rownames  district                     school       county grades  \
# 414       415     69682  Saratoga Union Elementary  Santa Clara  KK-08
# 415       416     68957     Las Lomitas Elementary    San Mateo  KK-08
# 416       417     69518       Los Altos Elementary  Santa Clara  KK-08
# 417       418     72611     Somis Union Elementary      Ventura  KK-08
# 418       419     72744          Plumas Elementary         Yuba  KK-08
# 419       420     72751       Wheatland Elementary         Yuba  KK-08
#
#      students    teachers  calworks      lunch  computer  expenditure  \
# 414      2341  124.089996    0.1709   0.598000       286  5392.638672
# 415       984   59.730000    0.1016   3.556900       195  7290.338867
# 416      3724  208.479996    1.0741   1.503800       721  5741.462891
# 417       441   20.150000    3.5635  37.193802        45  4402.831543
# 418       101    5.000000   11.8812  59.405899        14  4776.336426
# ...

# %%
df.min(numeric_only=True)
# Out:
# rownames           1.000000
# district       61382.000000
# students          81.000000
# teachers           4.850000
# calworks           0.000000
# lunch              0.000000
# computer           0.000000
# expenditure     3926.069580
# income             5.335000
# english            0.000000
# read             604.500000
# math             605.400024
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# rownames         420.000000
# district       75440.000000
# students       27176.000000
# teachers        1429.000000
# calworks          78.994202
# lunch            100.000000
# computer        3324.000000
# expenditure     7711.506836
# income            55.327999
# english           85.539719
# read             704.000000
# math             709.500000
# dtype: float64

# %%
df.dtypes
# Out:
# rownames         int64
# district         int64
# school          object
# county          object
# grades          object
# students         int64
# teachers       float64
# calworks       float64
# lunch          float64
# computer         int64
# expenditure    float64
# income         float64
# english        float64
# read           float64
# math           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rownames     420 non-null    int64
#  1   district     420 non-null    int64
#  2   school       420 non-null    object
#  3   county       420 non-null    object
#  4   grades       420 non-null    object
#  5   students     420 non-null    int64
#  6   teachers     420 non-null    float64
#  7   calworks     420 non-null    float64
#  8   lunch        420 non-null    float64
#  9   computer     420 non-null    int64
#  10  expenditure  420 non-null    float64
#  11  income       420 non-null    float64
#  12  english      420 non-null    float64
#  13  read         420 non-null    float64
#  14  math         420 non-null    float64
# dtypes: float64(8), int64(4), object(3)
# memory usage: 49.3+ KB

# %%
df['county'].dtypes
# Out:
# dtype('O')

# %%
df['lunch'].dtypes
# Out:
# dtype('float64')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=420, step=1), Index(['rownames', 'district', 'school', 'county', 'grades', 'students',
#        'teachers', 'calworks', 'lunch', 'computer', 'expenditure', 'income',
#        'english', 'read', 'math'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 6300

# %%
print(df.shape)
# Out:
# (420, 15)

# %%
print(df.values)
# Out:
# [[1 75119 'Sunol Glen Unified' ... 0.0 691.5999755859375 690.0]
#  [2 61499 'Manzanita Elementary' ... 4.583333492279053 660.5
#   661.9000244140625]
#  [3 61549 'Thermalito Union Elementary' ... 30.000001907348636
#   636.2999877929688 650.9000244140625]
#  ...
#  [418 72611 'Somis Union Elementary' ... 24.263038635253903
#   648.2999877929688 641.7000122070312]
#  [419 72744 'Plumas Elementary' ... 2.97029709815979 667.9000244140625
#   676.5]
#  [420 72751 'Wheatland Elementary' ... 5.005624294281006 660.5 651.0]]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 420

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 420

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 6300

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# rownames         int64
# district         int64
# school          object
# county          object
# grades          object
# students         int64
# teachers       float64
# calworks       float64
# lunch          float64
# computer         int64
# expenditure    float64
# income         float64
# english        float64
# read           float64
# math           float64
# dtype: object

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['rownames', 'district', 'school', 'county', 'grades', 'students',
#        'teachers', 'calworks', 'lunch', 'computer', 'expenditure', 'income',
#        'english', 'read', 'math'],
#       dtype='object')

# %%
df.describe()
# Out:
#          rownames      district      students     teachers    calworks  \
# count  420.000000    420.000000    420.000000   420.000000  420.000000
# mean   210.500000  67472.809524   2628.792857   129.067376   13.246042
# std    121.387808   3466.994655   3913.104985   187.912679   11.454821
# min      1.000000  61382.000000     81.000000     4.850000    0.000000
# 25%    105.750000  64307.750000    379.000000    19.662499    4.395375
# 50%    210.500000  67760.500000    950.500000    48.564999   10.520450
# 75%    315.250000  70419.000000   3008.000000   146.350002   18.981350
# max    420.000000  75440.000000  27176.000000  1429.000000   78.994202
#
#             lunch     computer  expenditure      income     english  \
# count  420.000000   420.000000   420.000000  420.000000  420.000000
# mean    44.705237   303.383333  5312.407541   15.316588   15.768155
# std     27.123381   441.341298   633.937053    7.225890   18.285927
# ...

# %%
df.median(numeric_only=True)
# Out:
# rownames         210.500000
# district       67760.500000
# students         950.500000
# teachers          48.564999
# calworks          10.520450
# lunch             41.750700
# computer         117.500000
# expenditure     5214.516602
# income            13.727800
# english            8.777634
# read             655.750000
# math             652.449982
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# rownames         210.500000
# district       67472.809524
# students        2628.792857
# teachers         129.067376
# calworks          13.246042
# lunch             44.705237
# computer         303.383333
# expenditure     5312.407541
# income            15.316588
# english           15.768155
# read             654.970477
# math             653.342619
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#      rownames  district  students  teachers  calworks  lunch  computer  \
# 0           1     61382     160.0       5.0       0.0    0.0      50.0
# 1           2     61457     474.0       NaN       NaN    NaN       NaN
# 2           3     61499       NaN       NaN       NaN    NaN       NaN
# 3           4     61507       NaN       NaN       NaN    NaN       NaN
# 4           5     61523       NaN       NaN       NaN    NaN       NaN
# ..        ...       ...       ...       ...       ...    ...       ...
# 415       416     75051       NaN       NaN       NaN    NaN       NaN
# 416       417     75085       NaN       NaN       NaN    NaN       NaN
# 417       418     75119       NaN       NaN       NaN    NaN       NaN
# 418       419     75135       NaN       NaN       NaN    NaN       NaN
# 419       420     75440       NaN       NaN       NaN    NaN       NaN
#
#      expenditure  income  english        read        math
# ...

# %%
df.std(numeric_only=True)
# Out:
# rownames        121.387808
# district       3466.994655
# students       3913.104985
# teachers        187.912679
# calworks         11.454821
# lunch            27.123381
# computer        441.341298
# expenditure     633.937053
# income            7.225890
# english          18.285927
# read             20.107980
# math             18.754202
# dtype: float64

# %%
df.sample(5)
# Out:
#      rownames  district                         school          county grades  \
# 246       247     67785       Mountain View Elementary  San Bernardino  KK-08
# 269       270     71084             Gratton Elementary      Stanislaus  KK-08
# 141       142     73726  Merced River Union Elementary          Merced  KK-08
# 206       207     70045            Junction Elementary          Shasta  KK-08
# 13         14     72181     Sunnyside Union Elementary          Tulare  KK-08
#
#      students    teachers   calworks      lunch  computer  expenditure  \
# 246      3182  153.199997   3.530500  26.943300       328  4777.512695
# 269       105    5.730000   0.000000   0.000000        16  4877.086426
# 141       227   11.600000  18.061701  59.030800        25  5519.677246
# 206       532   31.000000  10.506600  29.643499        81  5920.253418
# 13        487   24.340000  24.609400  77.148399         0  4818.612793
#
#      income    english        read        math
# ...

# %%
df.sample(20)
# Out:
#      rownames  district                       school         county grades  \
# 74         75     69203   Guadalupe Union Elementary  Santa Barbara  KK-08
# 67         68     63917           Hanford Elementary          Kings  KK-08
# 145       146     68205       Lemon Grove Elementary      San Diego  KK-08
# 341       342     61879    Gold Oak Union Elementary      El Dorado  KK-08
# 336       337     68049            Dehesa Elementary      San Diego  KK-06
# 131       132     63487   General Shafter Elementary           Kern  KK-08
# 237       238     66324       Clear Creek Elementary         Nevada  KK-08
# 371       372     70078   North Cow Creek Elementary         Shasta  KK-08
# 124       125     71837            Burton Elementary         Tulare  KK-08
# 398       399     69419   Cupertino Union Elementary    Santa Clara  KK-08
# 230       231     63883     Central Union Elementary          Kings  KK-08
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#      rownames  district                           school       county grades  \
# 0           1     75119               Sunol Glen Unified      Alameda  KK-08
# 1           2     61499             Manzanita Elementary        Butte  KK-08
# 2           3     61549      Thermalito Union Elementary        Butte  KK-08
# 3           4     61457  Golden Feather Union Elementary        Butte  KK-08
# 4           5     61523         Palermo Union Elementary        Butte  KK-08
# ..        ...       ...                              ...          ...    ...
# 415       416     68957           Las Lomitas Elementary    San Mateo  KK-08
# 416       417     69518             Los Altos Elementary  Santa Clara  KK-08
# 417       418     72611           Somis Union Elementary      Ventura  KK-08
# 418       419     72744                Plumas Elementary         Yuba  KK-08
# 419       420     72751             Wheatland Elementary         Yuba  KK-08
#
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# rownames          25.500000
# district       66606.320000
# students        3597.320000
# teachers         173.073599
# calworks          23.921212
# lunch             83.037800
# computer         357.300000
# expenditure     5300.675039
# income             9.665667
# english           44.631484
# read             623.932002
# math             627.574005
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# rownames         395.500000
# district       68518.300000
# students        1557.580000
# teachers          81.678840
# calworks           2.964096
# lunch              9.993326
# computer         244.640000
# expenditure     5826.156572
# income            28.277010
# english            4.126526
# read             686.290000
# math             684.074001
# dtype: float64

# %%
df.columns
# Out:
# Index(['rownames', 'district', 'school', 'county', 'grades', 'students',
#        'teachers', 'calworks', 'lunch', 'computer', 'expenditure', 'income',
#        'english', 'read', 'math'],
#       dtype='object')

# %%
df['rownames'].describe()
# Out:
# count    420.000000
# mean     210.500000
# std      121.387808
# min        1.000000
# 25%      105.750000
# 50%      210.500000
# 75%      315.250000
# max      420.000000
# Name: rownames, dtype: float64

# %%
df['district'].describe()
# Out:
# count      420.000000
# mean     67472.809524
# std       3466.994655
# min      61382.000000
# 25%      64307.750000
# 50%      67760.500000
# 75%      70419.000000
# max      75440.000000
# Name: district, dtype: float64

# %%
df['school']
# Out:
# 0                   Sunol Glen Unified
# 1                 Manzanita Elementary
# 2          Thermalito Union Elementary
# 3      Golden Feather Union Elementary
# 4             Palermo Union Elementary
#                     ...
# 415             Las Lomitas Elementary
# 416               Los Altos Elementary
# 417             Somis Union Elementary
# 418                  Plumas Elementary
# 419               Wheatland Elementary
# Name: school, Length: 420, dtype: object

# %%
df['computer'].count()
# Out:
# np.int64(420)

# %%
df['expenditure'].count()
# Out:
# np.int64(420)

# %%
df['district'].mean()
# Out:
# np.float64(67472.80952380953)

# %%
df['rownames'].mean()
# Out:
# np.float64(210.5)

# %%
df[10:20]
# Out:
#     rownames  district                         school       county grades  \
# 10        11     65722      Le Grand Union Elementary       Merced  KK-08
# 11        12     62174         West Fresno Elementary       Fresno  KK-08
# 12        13     71795         Allensworth Elementary       Tulare  KK-08
# 13        14     72181     Sunnyside Union Elementary       Tulare  KK-08
# 14        15     72298           Woodville Elementary       Tulare  KK-08
# 15        16     72041        Pixley Union Elementary       Tulare  KK-08
# 16        17     63594    Lost Hills Union Elementary         Kern  KK-08
# 17        18     63370  Buttonwillow Union Elementary         Kern  KK-08
# 18        19     64709              Lennox Elementary  Los Angeles  KK-08
# 19        20     63560              Lamont Elementary         Kern  KK-08
#
#     students    teachers   calworks      lunch  computer  expenditure  income  \
# ...

# %%
df[10:30]
# Out:
#     rownames  district                         school       county grades  \
# 10        11     65722      Le Grand Union Elementary       Merced  KK-08
# 11        12     62174         West Fresno Elementary       Fresno  KK-08
# 12        13     71795         Allensworth Elementary       Tulare  KK-08
# 13        14     72181     Sunnyside Union Elementary       Tulare  KK-08
# 14        15     72298           Woodville Elementary       Tulare  KK-08
# 15        16     72041        Pixley Union Elementary       Tulare  KK-08
# 16        17     63594    Lost Hills Union Elementary         Kern  KK-08
# 17        18     63370  Buttonwillow Union Elementary         Kern  KK-08
# 18        19     64709              Lennox Elementary  Los Angeles  KK-08
# 19        20     63560              Lamont Elementary         Kern  KK-08
# 20        21     63230   Westmorland Union Elementary     Imperial  KK-08
# 21        22     72058       Pleasant View Elementary       Tulare  KK-08
# ...

# %%
df.loc[10:20,['rownames', 'district', 'school', 'county']]
# Out:
#     rownames  district                         school       county
# 10        11     65722      Le Grand Union Elementary       Merced
# 11        12     62174         West Fresno Elementary       Fresno
# 12        13     71795         Allensworth Elementary       Tulare
# 13        14     72181     Sunnyside Union Elementary       Tulare
# 14        15     72298           Woodville Elementary       Tulare
# 15        16     72041        Pixley Union Elementary       Tulare
# 16        17     63594    Lost Hills Union Elementary         Kern
# 17        18     63370  Buttonwillow Union Elementary         Kern
# 18        19     64709              Lennox Elementary  Los Angeles
# 19        20     63560              Lamont Elementary         Kern
# 20        21     63230   Westmorland Union Elementary     Imperial

# %%
df.loc[10:20,['grades', 'students','teachers', 'calworks']]
# Out:
#    grades  students    teachers   calworks
# 10  KK-08       446   21.000000  18.609900
# 11  KK-08       987   47.000000  71.713097
# 12  KK-08       103    5.000000  22.429899
# 13  KK-08       487   24.340000  24.609400
# 14  KK-08       649   36.000000  14.637900
# 15  KK-08       852   42.070000  24.214199
# 16  KK-08       491   28.920000  11.201600
# 17  KK-08       421   25.500000   8.551100
# 18  KK-08      6880  303.029999  21.282400
# 19  KK-08      2688  135.000000  23.437500
# 20  KK-08       440   24.000000  34.772701

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#      rownames  district                           school       county grades  \
# 0           1     75119               Sunol Glen Unified      Alameda  KK-08
# 1           2     61499             Manzanita Elementary        Butte  KK-08
# 2           3     61549      Thermalito Union Elementary        Butte  KK-08
# 3           4     61457  Golden Feather Union Elementary        Butte  KK-08
# 4           5     61523         Palermo Union Elementary        Butte  KK-08
# ..        ...       ...                              ...          ...    ...
# 415       416     68957           Las Lomitas Elementary    San Mateo  KK-08
# 416       417     69518             Los Altos Elementary  Santa Clara  KK-08
# 417       418     72611           Somis Union Elementary      Ventura  KK-08
# 418       419     72744                Plumas Elementary         Yuba  KK-08
# 419       420     72751             Wheatland Elementary         Yuba  KK-08
#
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#      rownames  district                           school       county grades  \
# 0           1     75119               Sunol Glen Unified      Alameda  KK-08
# 1           2     61499             Manzanita Elementary        Butte  KK-08
# 2           3     61549      Thermalito Union Elementary        Butte  KK-08
# 3           4     61457  Golden Feather Union Elementary        Butte  KK-08
# 4           5     61523         Palermo Union Elementary        Butte  KK-08
# ..        ...       ...                              ...          ...    ...
# 415       416     68957           Las Lomitas Elementary    San Mateo  KK-08
# 416       417     69518             Los Altos Elementary  Santa Clara  KK-08
# 417       418     72611           Somis Union Elementary      Ventura  KK-08
# 418       419     72744                Plumas Elementary         Yuba  KK-08
# 419       420     72751             Wheatland Elementary         Yuba  KK-08
#
# ...

# %%
df.min()
# Out:
# rownames                         1
# district                     61382
# school         Ackerman Elementary
# county                     Alameda
# grades                       KK-06
# students                        81
# teachers                      4.85
# calworks                       0.0
# lunch                          0.0
# computer                         0
# expenditure             3926.06958
# income                       5.335
# english                        0.0
# read                         604.5
# math                    605.400024
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rownames     420 non-null    int64
#  1   district     420 non-null    int64
#  2   school       420 non-null    object
#  3   county       420 non-null    object
#  4   grades       420 non-null    object
#  5   students     420 non-null    int64
#  6   teachers     420 non-null    float64
#  7   calworks     420 non-null    float64
#  8   lunch        420 non-null    float64
#  9   computer     420 non-null    int64
#  10  expenditure  420 non-null    float64
#  11  income       420 non-null    float64
#  12  english      420 non-null    float64
#  13  read         420 non-null    float64
#  14  math         420 non-null    float64
# dtypes: float64(8), int64(4), object(3)
# memory usage: 49.3+ KB
