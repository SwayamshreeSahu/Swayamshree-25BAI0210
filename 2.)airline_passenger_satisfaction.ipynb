# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/airline_passenger_satisfaction.csv")

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.head(10)
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
# 5   6    Male   43     Returning       Business  Business             3788
# 6   7    Male   43     Returning       Business  Business             1963
# 7   8  Female   60     Returning       Business  Business              853
# 8   9    Male   50     Returning       Business  Business             2607
# 9  10  Female   38     Returning       Business  Business             2822
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# ...

# %%
df.head(10)
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
# 5   6    Male   43     Returning       Business  Business             3788
# 6   7    Male   43     Returning       Business  Business             1963
# 7   8  Female   60     Returning       Business  Business              853
# 8   9    Male   50     Returning       Business  Business             2607
# 9  10  Female   38     Returning       Business  Business             2822
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# ...

# %%
df.tail()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 129875                                       4  ...                 5
# ...

# %%
df.tail(5)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 129875                                       4  ...                 5
# ...

# %%
df.tail(20)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129860  129861  Female   30     Returning       Business      Business
# 129861  129862  Female   39     Returning       Business      Business
# 129862  129863    Male   51     Returning       Business      Business
# 129863  129864  Female   39     Returning       Business      Business
# 129864  129865    Male   38     Returning       Business      Business
# 129865  129866    Male   64     Returning       Business  Economy Plus
# 129866  129867  Female   20    First-time       Business       Economy
# 129867  129868    Male   47     Returning       Business  Economy Plus
# 129868  129869  Female   18    First-time       Business       Economy
# 129869  129870    Male   20    First-time       Business       Economy
# 129870  129871  Female   23    First-time       Business      Business
# 129871  129872  Female   32     Returning       Business  Economy Plus
# ...

# %%
df.min()
# Out:
# ID                                                              1
# Gender                                                     Female
# Age                                                             7
# Customer Type                                          First-time
# Type of Travel                                           Business
# Class                                                    Business
# Flight Distance                                                31
# Departure Delay                                                 0
# Arrival Delay                                                 0.0
# Departure and Arrival Time Convenience                          0
# Ease of Online Booking                                          0
# Check-in Service                                                0
# Online Boarding                                                 0
# Gate Location                                                   0
# ...

# %%
df.max()
# Out:
# ID                                              129880
# Gender                                            Male
# Age                                                 85
# Customer Type                                Returning
# Type of Travel                                Personal
# Class                                     Economy Plus
# Flight Distance                                   4983
# Departure Delay                                   1592
# Arrival Delay                                   1584.0
# Departure and Arrival Time Convenience               5
# Ease of Online Booking                               5
# Check-in Service                                     5
# Online Boarding                                      5
# Gate Location                                        5
# On-board Service                                     5
# Seat Comfort                                         5
# Leg Room Service                                     5
# ...

# %%
df.dtypes
# Out:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                             int64
# Departure Delay                             int64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience      int64
# Ease of Online Booking                      int64
# Check-in Service                            int64
# Online Boarding                             int64
# Gate Location                               int64
# On-board Service                            int64
# Seat Comfort                                int64
# Leg Room Service                            int64
# Cleanliness                                 int64
# Food and Drink                              int64
# ...

# %%
df['Class'].dtypes
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=129880, step=1), Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 3117120

# %%
print(df.shape)
# Out:
# (129880, 24)

# %%
print(df.values)
# Out:
# [[1 'Male' 48 ... 5 5 'Neutral or Dissatisfied']
#  [2 'Female' 35 ... 5 5 'Satisfied']
#  [3 'Male' 41 ... 3 3 'Satisfied']
#  ...
#  [129878 'Male' 42 ... 3 5 'Neutral or Dissatisfied']
#  [129879 'Male' 50 ... 3 5 'Satisfied']
#  [129880 'Female' 20 ... 2 1 'Neutral or Dissatisfied']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 129880

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 129880

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 3117120

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                             int64
# Departure Delay                             int64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience      int64
# Ease of Online Booking                      int64
# Check-in Service                            int64
# Online Boarding                             int64
# Gate Location                               int64
# On-board Service                            int64
# Seat Comfort                                int64
# Leg Room Service                            int64
# Cleanliness                                 int64
# Food and Drink                              int64
# ...

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                             int64
# Departure Delay                             int64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience      int64
# Ease of Online Booking                      int64
# Check-in Service                            int64
# Online Boarding                             int64
# Gate Location                               int64
# On-board Service                            int64
# Seat Comfort                                int64
# Leg Room Service                            int64
# Cleanliness                                 int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df.max()
# Out:
# ID                                              129880
# Gender                                            Male
# Age                                                 85
# Customer Type                                Returning
# Type of Travel                                Personal
# Class                                     Economy Plus
# Flight Distance                                   4983
# Departure Delay                                   1592
# Arrival Delay                                   1584.0
# Departure and Arrival Time Convenience               5
# Ease of Online Booking                               5
# Check-in Service                                     5
# Online Boarding                                      5
# Gate Location                                        5
# On-board Service                                     5
# Seat Comfort                                         5
# Leg Room Service                                     5
# ...

# %%
df.median(numeric_only=True)
# Out:
# ID                                        64940.5
# Age                                          40.0
# Flight Distance                             844.0
# Departure Delay                               0.0
# Arrival Delay                                 0.0
# Departure and Arrival Time Convenience        3.0
# Ease of Online Booking                        3.0
# Check-in Service                              3.0
# Online Boarding                               3.0
# Gate Location                                 3.0
# On-board Service                              4.0
# Seat Comfort                                  4.0
# Leg Room Service                              4.0
# Cleanliness                                   3.0
# Food and Drink                                3.0
# In-flight Service                             4.0
# In-flight Wifi Service                        3.0
# In-flight Entertainment                       4.0
# Baggage Handling                              4.0
# ...

# %%
df.mode(numeric_only=True)
# Out:
#             ID   Age  Flight Distance  Departure Delay  Arrival Delay  \
# 0            1  39.0            337.0              0.0            0.0
# 1            2   NaN              NaN              NaN            NaN
# 2            3   NaN              NaN              NaN            NaN
# 3            4   NaN              NaN              NaN            NaN
# 4            5   NaN              NaN              NaN            NaN
# ...        ...   ...              ...              ...            ...
# 129875  129876   NaN              NaN              NaN            NaN
# 129876  129877   NaN              NaN              NaN            NaN
# 129877  129878   NaN              NaN              NaN            NaN
# 129878  129879   NaN              NaN              NaN            NaN
# 129879  129880   NaN              NaN              NaN            NaN
#
#         Departure and Arrival Time Convenience  Ease of Online Booking  \
# ...

# %%
df.mean(numeric_only=True)
# Out:
# ID                                        64940.500000
# Age                                          39.427957
# Flight Distance                            1190.316392
# Departure Delay                              14.713713
# Arrival Delay                                15.091129
# Departure and Arrival Time Convenience        3.057599
# Ease of Online Booking                        2.756876
# Check-in Service                              3.306267
# Online Boarding                               3.252633
# Gate Location                                 2.976925
# On-board Service                              3.383023
# Seat Comfort                                  3.441361
# Leg Room Service                              3.350878
# Cleanliness                                   3.286326
# Food and Drink                                3.204774
# In-flight Service                             3.642193
# In-flight Wifi Service                        2.728696
# ...

# %%
df.mean(numeric_only=True)
# Out:
# ID                                        64940.500000
# Age                                          39.427957
# Flight Distance                            1190.316392
# Departure Delay                              14.713713
# Arrival Delay                                15.091129
# Departure and Arrival Time Convenience        3.057599
# Ease of Online Booking                        2.756876
# Check-in Service                              3.306267
# Online Boarding                               3.252633
# Gate Location                                 2.976925
# On-board Service                              3.383023
# Seat Comfort                                  3.441361
# Leg Room Service                              3.350878
# Cleanliness                                   3.286326
# Food and Drink                                3.204774
# In-flight Service                             3.642193
# In-flight Wifi Service                        2.728696
# ...

# %%
# Display a random sample of 5 rows
df.sample(5)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 54568    54569  Female   26    First-time       Business  Economy Plus
# 103502  103503  Female   49     Returning       Business      Business
# 24804    24805  Female   17     Returning       Personal      Business
# 70470    70471    Male   41     Returning       Business      Business
# 15440    15441  Female   21     Returning       Business      Business
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 54568               925                1            4.0
# 103502             1779                5            0.0
# 24804               894               40           35.0
# 70470              2293                0            5.0
# 15440              2574               13            0.0
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 54568                                        3  ...                 3
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['Age',
#  'Class',
#  'Cleanliness',
#  'Gender',
#  'ID',
#  'Satisfaction',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# ID                                          25.50
# Age                                         43.08
# Flight Distance                           1199.60
# Departure Delay                              7.16
# Arrival Delay                               10.66
# Departure and Arrival Time Convenience       3.10
# Ease of Online Booking                       2.74
# Check-in Service                             3.82
# Online Boarding                              3.68
# Gate Location                                3.06
# On-board Service                             3.78
# Seat Comfort                                 3.98
# Leg Room Service                             3.74
# Cleanliness                                  3.88
# Food and Drink                               3.36
# In-flight Service                            4.14
# In-flight Wifi Service                       2.68
# In-flight Entertainment                      4.02
# ...

# %%
print("Mean values of the first 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# ID                                        129855.50
# Age                                           37.68
# Flight Distance                              605.58
# Departure Delay                               16.98
# Arrival Delay                                 18.18
# Departure and Arrival Time Convenience         3.04
# Ease of Online Booking                         2.42
# Check-in Service                               3.34
# Online Boarding                                3.16
# Gate Location                                  2.96
# On-board Service                               3.52
# Seat Comfort                                   3.50
# Leg Room Service                               3.44
# Cleanliness                                    3.58
# Food and Drink                                 3.18
# In-flight Service                              3.76
# In-flight Wifi Service                         2.24
# ...

# %%
df['Departure Delay']
# Out:
# 0          2
# 1         26
# 2          0
# 3          0
# 4          0
#           ..
# 129875     2
# 129876     0
# 129877     6
# 129878    31
# 129879     0
# Name: Departure Delay, Length: 129880, dtype: int64

# %%
df['Departure and Arrival Time Convenience']
# Out:
# 0         3
# 1         2
# 2         4
# 3         2
# 4         3
#          ..
# 129875    4
# 129876    5
# 129877    5
# 129878    4
# 129879    1
# Name: Departure and Arrival Time Convenience, Length: 129880, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %%
df['Online Boarding'].describe()
# Out:
# count    129880.000000
# mean          3.252633
# std           1.350719
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Online Boarding, dtype: float64

# %%
df['Online Boarding'].count()
# Out:
# np.int64(129880)

# %%
df['Online Boarding'].mean()
# Out:
# np.float64(3.252633199876809)

# %%
df[30:40]
# Out:
#     ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 30  31    Male   35    First-time       Business  Business              212
# 31  32    Male   21    First-time       Business   Economy              173
# 32  33  Female   33    First-time       Business  Business              173
# 33  34  Female   48     Returning       Business  Business              173
# 34  35    Male   39     Returning       Business  Business             1672
# 35  36  Female   42     Returning       Business  Business             2884
# 36  37  Female   54     Returning       Business  Business              212
# 37  38  Female   51     Returning       Business  Business              215
# 38  39  Female   46     Returning       Business  Business               67
# 39  40    Male   51     Returning       Business  Business              212
#
#     Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# ...

# %%
df.loc[30:40,['Gender','Age','Customer Type','Type of Travel']]
# Out:
#     Gender  Age Customer Type Type of Travel
# 30    Male   35    First-time       Business
# 31    Male   21    First-time       Business
# 32  Female   33    First-time       Business
# 33  Female   48     Returning       Business
# 34    Male   39     Returning       Business
# 35  Female   42     Returning       Business
# 36  Female   54     Returning       Business
# 37  Female   51     Returning       Business
# 38  Female   46     Returning       Business
# 39    Male   51     Returning       Business
# 40  Female   54     Returning       Business

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...
