# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
Dataset = {
    'Employee ID': np.arange(1, 21),
    'Name': [f'Employee_{i}' for i in range(1, 21)],
    'Department': np.random.choice(['HR', 'Engineering', 'Marketing', 'Sales', 'Finance'], 20),
    'Age': np.random.randint(22, 60, 20),
    'Salary': np.random.randint(40000, 120000, 20)
}
df = pd.DataFrame(Dataset)
df
# Out:
#     Employee ID         Name   Department  Age  Salary
# 0             1   Employee_1      Finance   34   66246
# 1             2   Employee_2  Engineering   23   41483
# 2             3   Employee_3           HR   24   56552
# 3             4   Employee_4  Engineering   43   99757
# 4             5   Employee_5    Marketing   55   85252
# 5             6   Employee_6      Finance   29  116474
# 6             7   Employee_7           HR   30   73909
# 7             8   Employee_8      Finance   27   95401
# 8             9   Employee_9        Sales   53   76869
# 9            10  Employee_10        Sales   44  103550
# 10           11  Employee_11        Sales   55   55806
# 11           12  Employee_12           HR   32   74273
# 12           13  Employee_13      Finance   50   49875
# 13           14  Employee_14        Sales   49   45992
# 14           15  Employee_15        Sales   57   45402
# 15           16  Employee_16      Finance   37   78092
# 16           17  Employee_17      Finance   59  113413
# 17           18  Employee_18           HR   30   83719
# 18           19  Employee_19           HR   26   44216
# 19           20  Employee_20    Marketing   49   57891

# %%
df.head()
# Out:
#    Employee ID        Name   Department  Age  Salary
# 0            1  Employee_1      Finance   34   66246
# 1            2  Employee_2  Engineering   23   41483
# 2            3  Employee_3           HR   24   56552
# 3            4  Employee_4  Engineering   43   99757
# 4            5  Employee_5    Marketing   55   85252

# %%
df.tail()
# Out:
#     Employee ID         Name Department  Age  Salary
# 15           16  Employee_16    Finance   37   78092
# 16           17  Employee_17    Finance   59  113413
# 17           18  Employee_18         HR   30   83719
# 18           19  Employee_19         HR   26   44216
# 19           20  Employee_20  Marketing   49   57891

# %%
display(df.columns.tolist())
# Out:
# ['Employee ID', 'Name', 'Department', 'Age', 'Salary']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee ID  20 non-null     int64
#  1   Name         20 non-null     object
#  2   Department   20 non-null     object
#  3   Age          20 non-null     int64
#  4   Salary       20 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 932.0+ bytes

# %%
df.describe()
# Out:
#        Employee ID        Age         Salary
# count     20.00000  20.000000      20.000000
# mean      10.50000  40.300000   73208.600000
# std        5.91608  12.342055   23697.081978
# min        1.00000  23.000000   41483.000000
# 25%        5.75000  29.750000   54323.250000
# 50%       10.50000  40.000000   74091.000000
# 75%       15.25000  50.750000   87789.250000
# max       20.00000  59.000000  116474.000000

# %%
df.isnull().sum()
# Out:
# Employee ID    0
# Name           0
# Department     0
# Age            0
# Salary         0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Employee ID    0.0
# Name           0.0
# Department     0.0
# Age            0.0
# Salary         0.0
# dtype: float64
