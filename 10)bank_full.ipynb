# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/bank-full.csv", sep=';')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
df.head(20)
# Out:
#     age          job   marital            education  default housing loan  \
# 0    56    housemaid   married             basic.4y       no      no   no
# 1    57     services   married          high.school  unknown      no   no
# 2    37     services   married          high.school       no     yes   no
# 3    40       admin.   married             basic.6y       no      no   no
# 4    56     services   married          high.school       no      no  yes
# 5    45     services   married             basic.9y  unknown      no   no
# 6    59       admin.   married  professional.course       no      no   no
# 7    41  blue-collar   married              unknown  unknown      no   no
# 8    24   technician    single  professional.course       no     yes   no
# 9    25     services    single          high.school       no     yes   no
# 10   41  blue-collar   married              unknown  unknown      no   no
# 11   25     services    single          high.school       no     yes   no
# ...

# %%
df.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.tail(6)
# Out:
#        age          job  marital            education default housing loan  \
# 41182   29   unemployed   single             basic.4y      no     yes   no
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41182  cellular   nov         fri  ...         1      9         1
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# ...

# %%
df.min(numeric_only=True)
# Out:
# age                 17.000
# duration             0.000
# campaign             1.000
# pdays                0.000
# previous             0.000
# emp.var.rate        -3.400
# cons.price.idx      92.201
# cons.conf.idx      -50.800
# euribor3m            0.634
# nr.employed       4963.600
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# age                 98.000
# duration          4918.000
# campaign            56.000
# pdays              999.000
# previous             7.000
# emp.var.rate         1.400
# cons.price.idx      94.767
# cons.conf.idx      -26.900
# euribor3m            5.045
# nr.employed       5228.100
# dtype: float64

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df['age'].dtypes
# Out:
# dtype('int64')

# %%
df['job'].dtypes
# Out:
# dtype('O')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=41188, step=1), Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 864948

# %%
print(df.shape)
# Out:
# (41188, 21)

# %%
print(df.values)
# Out:
# [[56 'housemaid' 'married' ... 4.857 5191.0 'no']
#  [57 'services' 'married' ... 4.857 5191.0 'no']
#  [37 'services' 'married' ... 4.857 5191.0 'no']
#  ...
#  [56 'retired' 'married' ... 1.028 4963.6 'no']
#  [44 'technician' 'married' ... 1.028 4963.6 'yes']
#  [74 'retired' 'married' ... 1.028 4963.6 'no']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 41188

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 41188

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 864948

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df.median(numeric_only=True)
# Out:
# age                 38.000
# duration           180.000
# campaign             2.000
# pdays              999.000
# previous             0.000
# emp.var.rate         1.100
# cons.price.idx      93.749
# cons.conf.idx      -41.800
# euribor3m            4.857
# nr.employed       5191.000
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# age                 40.024060
# duration           258.285010
# campaign             2.567593
# pdays              962.475454
# previous             0.172963
# emp.var.rate         0.081886
# cons.price.idx      93.575664
# cons.conf.idx      -40.502600
# euribor3m            3.621291
# nr.employed       5167.035911
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#     age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0  31.0        85       1.0  999.0       0.0           1.4          93.994
# 1   NaN        90       NaN    NaN       NaN           NaN             NaN
#
#    cons.conf.idx  euribor3m  nr.employed
# 0          -36.4      4.857       5228.1
# 1            NaN        NaN          NaN

# %%
df.std(numeric_only=True)
# Out:
# age                10.421250
# duration          259.279249
# campaign            2.770014
# pdays             186.910907
# previous            0.494901
# emp.var.rate        1.570960
# cons.price.idx      0.578840
# cons.conf.idx       4.628198
# euribor3m           1.734447
# nr.employed        72.251528
# dtype: float64

# %%
df.sample(5)
# Out:
#        age          job  marital            education  default housing loan  \
# 14181   38  blue-collar  married          high.school  unknown      no   no
# 33618   42     services   single             basic.6y       no     yes   no
# 19981   49     services  married          high.school  unknown     yes   no
# 19422   31     services  married  professional.course  unknown      no  yes
# 36278   49   management  married    university.degree       no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 14181  cellular   jul         mon  ...         3    999         0
# 33618  cellular   may         wed  ...         5    999         0
# 19981  cellular   aug         fri  ...         2    999         0
# 19422  cellular   aug         wed  ...         2    999         0
# 36278  cellular   jun         mon  ...         1    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.sample(20)
# Out:
#        age           job   marital            education  default housing loan  \
# 20926   32        admin.    single    university.degree       no     yes   no
# 14002   29      services   married             basic.9y       no     yes   no
# 2704    34    technician    single  professional.course       no      no   no
# 13334   37  entrepreneur  divorced    university.degree       no      no  yes
# 8760    43    technician   married  professional.course       no      no   no
# 24602   35   blue-collar   married             basic.9y       no     yes   no
# 24178   54    technician   married  professional.course       no      no   no
# 38035   56  entrepreneur   married    university.degree       no     yes   no
# 19033   29        admin.    single    university.degree       no      no   no
# 11946   36    technician   married             basic.9y       no      no   no
# 32451   33        admin.   married             basic.9y       no     yes   no
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# age                 45.180
# duration           268.080
# campaign             1.040
# pdays              999.000
# previous             0.000
# emp.var.rate         1.100
# cons.price.idx      93.994
# cons.conf.idx      -36.400
# euribor3m            4.857
# nr.employed       5191.000
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# age                 42.14000
# duration           364.42000
# campaign             2.18000
# pdays              780.80000
# previous             0.90000
# emp.var.rate        -1.10000
# cons.price.idx      94.76700
# cons.conf.idx      -50.80000
# euribor3m            1.03434
# nr.employed       4963.60000
# dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df['age']
# Out:
# 0        56
# 1        57
# 2        37
# 3        40
# 4        56
#          ..
# 41183    73
# 41184    46
# 41185    56
# 41186    44
# 41187    74
# Name: age, Length: 41188, dtype: int64

# %%
df['month'].describe()
# Out:
# count     41188
# unique       10
# top         may
# freq      13769
# Name: month, dtype: object

# %%
df['day_of_week'].describe()
# Out:
# count     41188
# unique        5
# top         thu
# freq       8623
# Name: day_of_week, dtype: object

# %%
df['euribor3m'].count()
# Out:
# np.int64(41188)

# %%
df['nr.employed'].count()
# Out:
# np.int64(41188)

# %%
df['age'].mean()
# Out:
# np.float64(40.02406040594348)

# %%
df[10:20]
# Out:
#     age          job   marital    education  default housing loan    contact  \
# 10   41  blue-collar   married      unknown  unknown      no   no  telephone
# 11   25     services    single  high.school       no     yes   no  telephone
# 12   29  blue-collar    single  high.school       no      no  yes  telephone
# 13   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 14   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 15   54      retired   married     basic.9y  unknown     yes  yes  telephone
# 16   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 17   46  blue-collar   married     basic.6y  unknown     yes  yes  telephone
# 18   50  blue-collar   married     basic.9y       no     yes  yes  telephone
# 19   39   management    single     basic.9y  unknown      no   no  telephone
#
#    month day_of_week  ...  campaign  pdays  previous     poutcome  \
# ...

# %%
df[10:30]
# Out:
#     age            job   marital          education  default  housing  \
# 10   41    blue-collar   married            unknown  unknown       no
# 11   25       services    single        high.school       no      yes
# 12   29    blue-collar    single        high.school       no       no
# 13   57      housemaid  divorced           basic.4y       no      yes
# 14   35    blue-collar   married           basic.6y       no      yes
# 15   54        retired   married           basic.9y  unknown      yes
# 16   35    blue-collar   married           basic.6y       no      yes
# 17   46    blue-collar   married           basic.6y  unknown      yes
# 18   50    blue-collar   married           basic.9y       no      yes
# 19   39     management    single           basic.9y  unknown       no
# 20   30     unemployed   married        high.school       no       no
# 21   55    blue-collar   married           basic.4y  unknown      yes
# ...

# %%
df.loc[10:20,['age', 'job', 'marital', 'education']]
# Out:
#     age          job   marital    education
# 10   41  blue-collar   married      unknown
# 11   25     services    single  high.school
# 12   29  blue-collar    single  high.school
# 13   57    housemaid  divorced     basic.4y
# 14   35  blue-collar   married     basic.6y
# 15   54      retired   married     basic.9y
# 16   35  blue-collar   married     basic.6y
# 17   46  blue-collar   married     basic.6y
# 18   50  blue-collar   married     basic.9y
# 19   39   management    single     basic.9y
# 20   30   unemployed   married  high.school

# %%
df.loc[10:20,['cons.conf.idx', 'euribor3m', 'nr.employed']]
# Out:
#     cons.conf.idx  euribor3m  nr.employed
# 10          -36.4      4.857       5191.0
# 11          -36.4      4.857       5191.0
# 12          -36.4      4.857       5191.0
# 13          -36.4      4.857       5191.0
# 14          -36.4      4.857       5191.0
# 15          -36.4      4.857       5191.0
# 16          -36.4      4.857       5191.0
# 17          -36.4      4.857       5191.0
# 18          -36.4      4.857       5191.0
# 19          -36.4      4.857       5191.0
# 20          -36.4      4.857       5191.0

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.min()
# Out:
# age                     17
# job                 admin.
# marital           divorced
# education         basic.4y
# default                 no
# housing                 no
# loan                    no
# contact           cellular
# month                  apr
# day_of_week            fri
# duration                 0
# campaign                 1
# pdays                    0
# previous                 0
# poutcome           failure
# emp.var.rate          -3.4
# cons.price.idx      92.201
# cons.conf.idx        -50.8
# euribor3m            0.634
# nr.employed         4963.6
# y                       no
# dtype: object

# %%
df.max()
# Out:
# age                      98
# job                 unknown
# marital             unknown
# education           unknown
# default                 yes
# housing                 yes
# loan                    yes
# contact           telephone
# month                   sep
# day_of_week             wed
# duration               4918
# campaign                 56
# pdays                   999
# previous                  7
# poutcome            success
# emp.var.rate            1.4
# cons.price.idx       94.767
# cons.conf.idx         -26.9
# euribor3m             5.045
# nr.employed          5228.1
# y                       yes
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...
