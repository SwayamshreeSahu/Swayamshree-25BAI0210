# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/1000 Sales Records.csv")

# %%
df.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
df.head(10)
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
# 9              Australia and Oceania        Fiji  Vegetables       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
df.head(20)
# Out:
#                                Region     Country        Item Type  \
# 0        Middle East and North Africa       Libya        Cosmetics
# 1                       North America      Canada       Vegetables
# 2        Middle East and North Africa       Libya        Baby Food
# 3                                Asia       Japan           Cereal
# 4                  Sub-Saharan Africa        Chad           Fruits
# 5                              Europe     Armenia           Cereal
# 6                  Sub-Saharan Africa     Eritrea           Cereal
# 7                              Europe  Montenegro          Clothes
# 8   Central America and the Caribbean     Jamaica       Vegetables
# 9               Australia and Oceania        Fiji       Vegetables
# 10                 Sub-Saharan Africa        Togo          Clothes
# 11                             Europe  Montenegro           Snacks
# 12                             Europe      Greece        Household
# ...

# %%
df.tail()
# Out:
#                            Region               Country   Item Type  \
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 995       Offline              C  4/18/2010  534085166  4/25/2010        6524
# 996       Offline              H   8/1/2011  590768182   9/7/2011         288
# 997        Online              C  5/12/2011  524363124  6/28/2011        9556
# 998       Offline              L  1/25/2016  289606320  2/14/2016        9801
# 999       Offline              C  4/10/2014  811546599   5/8/2014        3528
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.tail(5)
# Out:
#                            Region               Country   Item Type  \
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 995       Offline              C  4/18/2010  534085166  4/25/2010        6524
# 996       Offline              H   8/1/2011  590768182   9/7/2011         288
# 997        Online              C  5/12/2011  524363124  6/28/2011        9556
# 998       Offline              L  1/25/2016  289606320  2/14/2016        9801
# 999       Offline              C  4/10/2014  811546599   5/8/2014        3528
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.tail(10)
# Out:
#                            Region               Country   Item Type  \
# 990            Sub-Saharan Africa                  Mali   Beverages
# 991            Sub-Saharan Africa               Liberia      Cereal
# 992                        Europe           Switzerland   Beverages
# 993         Australia and Oceania                Samoa    Baby Food
# 994                          Asia                 Nepal        Meat
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 990        Online              L   3/17/2012  410452497  3/26/2012
# 991       Offline              H  12/17/2015  642683303  1/20/2016
# ...

# %%
df.min()
# Out:
# Region                   Asia
# Country           Afghanistan
# Item Type           Baby Food
# Sales Channel         Offline
# Order Priority              C
# Order Date           1/1/2010
# Order ID            102928006
# Ship Date            1/1/2013
# Units Sold                 13
# Unit Price               9.33
# Unit Cost                6.92
# Total Revenue         2043.25
# Total Cost            1416.75
# Total Profit           532.61
# dtype: object

# %%
df.max()
# Out:
# Region            Sub-Saharan Africa
# Country                     Zimbabwe
# Item Type                 Vegetables
# Sales Channel                 Online
# Order Priority                     M
# Order Date                  9/8/2015
# Order ID                   995529830
# Ship Date                   9/9/2016
# Units Sold                      9998
# Unit Price                    668.27
# Unit Cost                     524.96
# Total Revenue             6617209.54
# Total Cost                 5204978.4
# Total Profit              1726181.36
# dtype: object

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
df['Order ID'].dtypes
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   object
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
print(df.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=1000, step=1), Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 14000

# %%
print(df.shape)
# Out:
# (1000, 14)

# %%
print(df.values)
# Out:
# [['Middle East and North Africa' 'Libya' 'Cosmetics' ... 3692591.2
#   2224085.18 1468506.02]
#  ['North America' 'Canada' 'Vegetables' ... 464953.08 274426.74 190526.34]
#  ['Middle East and North Africa' 'Libya' 'Baby Food' ... 387259.76
#   241840.14 145419.62]
#  ...
#  ['Middle East and North Africa' 'United Arab Emirates' 'Vegetables' ...
#   1472197.36 868927.08 603270.28]
#  ['Europe' 'Finland' 'Household' ... 6549714.27 4925394.54 1624319.73]
#  ['Europe' 'Portugal' 'Cereal' ... 725709.6 413164.08 312545.52]]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 1000

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 1000

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 14000

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# ...

# %%
df.max()
# Out:
# Region            Sub-Saharan Africa
# Country                     Zimbabwe
# Item Type                 Vegetables
# Sales Channel                 Online
# Order Priority                     M
# Order Date                  9/8/2015
# Order ID                   995529830
# Ship Date                   9/9/2016
# Units Sold                      9998
# Unit Price                    668.27
# Unit Cost                     524.96
# Total Revenue             6617209.54
# Total Cost                 5204978.4
# Total Profit              1726181.36
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# Order ID         5.566097e+08
# Units Sold       5.184000e+03
# Unit Price       1.540600e+02
# Unit Cost        9.744000e+01
# Total Revenue    7.549392e+05
# Total Cost       4.647261e+05
# Total Profit     2.772260e+05
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#       Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0    102928006      6283.0       47.45      31.79       90211.77    66909.48
# 1    103617227         NaN         NaN        NaN            NaN         NaN
# 2    104845464         NaN         NaN        NaN            NaN         NaN
# 3    105117976         NaN         NaN        NaN            NaN         NaN
# 4    105390059         NaN         NaN        NaN            NaN         NaN
# ..         ...         ...         ...        ...            ...         ...
# 995  990708720         NaN         NaN        NaN            NaN         NaN
# 996  991644704         NaN         NaN        NaN            NaN         NaN
# 997  991831386         NaN         NaN        NaN            NaN         NaN
# 998  994566810         NaN         NaN        NaN            NaN         NaN
# 999  995529830         NaN         NaN        NaN            NaN         NaN
#
#      Total Profit
# 0        23302.29
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Order ID         5.496813e+08
# Units Sold       5.053988e+03
# Unit Price       2.621068e+02
# Unit Cost        1.849651e+02
# Total Revenue    1.327322e+06
# Total Cost       9.361192e+05
# Total Profit     3.912026e+05
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Order ID         2.571334e+08
# Units Sold       2.901375e+03
# Unit Price       2.160211e+02
# Unit Cost        1.752893e+02
# Total Revenue    1.486515e+06
# Total Cost       1.162571e+06
# Total Profit     3.836402e+05
# dtype: float64

# %%
# Display a random sample of 5 rows
df.sample(5)
# Out:
#                     Region       Country      Item Type Sales Channel  \
# 229                 Europe        Norway        Clothes        Online
# 636  Australia and Oceania        Tuvalu         Cereal       Offline
# 261     Sub-Saharan Africa  Burkina Faso      Household        Online
# 352                 Europe         Italy         Cereal       Offline
# 800                 Europe     Macedonia  Personal Care       Offline
#
#     Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 229              H   4/7/2010  126767909  5/22/2010        2296      109.28
# 636              C  2/12/2014  133362710  3/23/2014        3844      205.70
# 261              M  2/28/2011  778490626  3/24/2011        1531      668.27
# 352              C  5/11/2013  622791612  5/31/2013        6733      205.70
# 800              H   2/2/2017  276694810  2/16/2017        8998       81.73
#
#      Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['Country',
#  'Region',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# Order ID         4.844509e+08
# Units Sold       5.037020e+03
# Unit Price       2.611640e+02
# Unit Cost        1.881152e+02
# Total Revenue    1.322732e+06
# Total Cost       9.690889e+05
# Total Profit     3.536435e+05
# dtype: float64

# %%
print("Mean values of the first 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# Order ID         5.626138e+08
# Units Sold       5.171300e+03
# Unit Price       2.687138e+02
# Unit Cost        1.897814e+02
# Total Revenue    1.564271e+06
# Total Cost       1.119927e+06
# Total Profit     4.443442e+05
# dtype: float64

# %%
df['Total Revenue']
# Out:
# 0      3692591.20
# 1       464953.08
# 2       387259.76
# 3       683335.40
# 4        91853.85
#           ...
# 995     995431.92
# 996      73520.64
# 997    1472197.36
# 998    6549714.27
# 999     725709.60
# Name: Total Revenue, Length: 1000, dtype: float64

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df['Order Priority'].describe()
# Out:
# count     1000
# unique       4
# top          L
# freq       268
# Name: Order Priority, dtype: object

# %%
df['Order Priority'].count()
# Out:
# np.int64(1000)

# %%
df['Order ID'].mean()
# Out:
# np.float64(549681324.743)

# %%
df[10:20]
# Out:
#                 Region     Country        Item Type Sales Channel  \
# 10  Sub-Saharan Africa        Togo          Clothes        Online
# 11              Europe  Montenegro           Snacks       Offline
# 12              Europe      Greece        Household        Online
# 13  Sub-Saharan Africa       Sudan        Cosmetics        Online
# 14                Asia    Maldives           Fruits       Offline
# 15              Europe  Montenegro          Clothes       Offline
# 16              Europe     Estonia  Office Supplies        Online
# 17       North America   Greenland        Beverages        Online
# 18  Sub-Saharan Africa  Cape Verde          Clothes        Online
# 19  Sub-Saharan Africa     Senegal        Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 10              M  12/29/2015  451010930   1/19/2016        3012      109.28
# 11              M   2/27/2010  220003211   3/18/2010        2694      152.58
# ...

# %%
df_sub.loc[10:20,['Region','Country','Item Type','Sales Channel']]
# Out:
#                    Region                         Country        Item Type  \
# 10     Sub-Saharan Africa                            Togo          Clothes
# 11                 Europe                      Montenegro           Snacks
# 12                 Europe                          Greece        Household
# 13     Sub-Saharan Africa                           Sudan        Cosmetics
# 14                   Asia                        Maldives           Fruits
# 15                 Europe                      Montenegro          Clothes
# 16                 Europe                         Estonia  Office Supplies
# 17          North America                       Greenland        Beverages
# 18     Sub-Saharan Africa                      Cape Verde          Clothes
# 19     Sub-Saharan Africa                         Senegal        Household
# 20  Australia and Oceania  Federated States of Micronesia           Snacks
#
#    Sales Channel
# 10        Online
# 11       Offline
# ...

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...
