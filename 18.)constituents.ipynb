# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/constituents.csv")

# %%
df.head()
# Out:
#   Symbol             Security             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
df.head(10)
# Out:
#   Symbol                Security             GICS Sector  \
# 0    MMM                      3M             Industrials
# 1    AOS             A. O. Smith             Industrials
# 2    ABT     Abbott Laboratories             Health Care
# 3   ABBV                  AbbVie             Health Care
# 4    ACN               Accenture  Information Technology
# 5   ADBE              Adobe Inc.  Information Technology
# 6    AMD  Advanced Micro Devices  Information Technology
# 7    AES         AES Corporation               Utilities
# 8    AFL                   Aflac              Financials
# 9      A    Agilent Technologies             Health Care
#
#                               GICS Sub-Industry    Headquarters Location  \
# 0                      Industrial Conglomerates    Saint Paul, Minnesota
# 1                             Building Products     Milwaukee, Wisconsin
# 2                         Health Care Equipment  North Chicago, Illinois
# ...

# %%
df.head(20)
# Out:
#    Symbol                         Security             GICS Sector  \
# 0     MMM                               3M             Industrials
# 1     AOS                      A. O. Smith             Industrials
# 2     ABT              Abbott Laboratories             Health Care
# 3    ABBV                           AbbVie             Health Care
# 4     ACN                        Accenture  Information Technology
# 5    ADBE                       Adobe Inc.  Information Technology
# 6     AMD           Advanced Micro Devices  Information Technology
# 7     AES                  AES Corporation               Utilities
# 8     AFL                            Aflac              Financials
# 9       A             Agilent Technologies             Health Care
# 10    APD                     Air Products               Materials
# 11   ABNB                           Airbnb  Consumer Discretionary
# 12   AKAM              Akamai Technologies  Information Technology
# ...

# %%
df.tail()
# Out:
#     Symbol            Security             GICS Sector  \
# 498    XYL          Xylem Inc.             Industrials
# 499    YUM         Yum! Brands  Consumer Discretionary
# 500   ZBRA  Zebra Technologies  Information Technology
# 501    ZBH       Zimmer Biomet             Health Care
# 502    ZTS              Zoetis             Health Care
#
#                                 GICS Sub-Industry   Headquarters Location  \
# 498  Industrial Machinery & Supplies & Components  White Plains, New York
# 499                                   Restaurants    Louisville, Kentucky
# 500            Electronic Equipment & Instruments  Lincolnshire, Illinois
# 501                         Health Care Equipment         Warsaw, Indiana
# 502                               Pharmaceuticals  Parsippany, New Jersey
#
#      Date added      CIK Founded
# 498  2011-11-01  1524472    2011
# 499  1997-10-06  1041061    1997
# 500  2019-12-23   877212    1969
# 501  2001-08-07  1136869    1927
# ...

# %%
df.tail(12)
# Out:
#     Symbol                      Security             GICS Sector  \
# 491    WST  West Pharmaceutical Services             Health Care
# 492    WDC               Western Digital  Information Technology
# 493     WY                  Weyerhaeuser             Real Estate
# 494    WMB            Williams Companies                  Energy
# 495    WTW          Willis Towers Watson              Financials
# 496   WYNN                  Wynn Resorts  Consumer Discretionary
# 497    XEL                   Xcel Energy               Utilities
# 498    XYL                    Xylem Inc.             Industrials
# 499    YUM                   Yum! Brands  Consumer Discretionary
# 500   ZBRA            Zebra Technologies  Information Technology
# 501    ZBH                 Zimmer Biomet             Health Care
# 502    ZTS                        Zoetis             Health Care
#
#                                 GICS Sub-Industry   Headquarters Location  \
# ...

# %%
df.min(numeric_only=True)
# Out:
# CIK    1800
# dtype: int64

# %%
df.max(numeric_only=True)
# Out:
# CIK    2005951
# dtype: int64

# %%
df.dtypes
# Out:
# Symbol                   object
# Security                 object
# GICS Sector              object
# GICS Sub-Industry        object
# Headquarters Location    object
# Date added               object
# CIK                       int64
# Founded                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 503 non-null    object
#  1   Security               503 non-null    object
#  2   GICS Sector            503 non-null    object
#  3   GICS Sub-Industry      503 non-null    object
#  4   Headquarters Location  503 non-null    object
#  5   Date added             503 non-null    object
#  6   CIK                    503 non-null    int64
#  7   Founded                503 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 31.6+ KB

# %%
df['Security'].dtypes
# Out:
# dtype('O')

# %%
df['GICS Sub-Industry'].dtypes
# Out:
# dtype('O')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=503, step=1), Index(['Symbol', 'Security', 'GICS Sector', 'GICS Sub-Industry',
#        'Headquarters Location', 'Date added', 'CIK', 'Founded'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 4024

# %%
print(df.shape)
# Out:
# (503, 8)

# %%
print(df.values)
# Out:
# [['MMM' '3M' 'Industrials' ... '1957-03-04' 66740 '1902']
#  ['AOS' 'A. O. Smith' 'Industrials' ... '2017-07-26' 91142 '1916']
#  ['ABT' 'Abbott Laboratories' 'Health Care' ... '1957-03-04' 1800 '1888']
#  ...
#  ['ZBRA' 'Zebra Technologies' 'Information Technology' ... '2019-12-23'
#   877212 '1969']
#  ['ZBH' 'Zimmer Biomet' 'Health Care' ... '2001-08-07' 1136869 '1927']
#  ['ZTS' 'Zoetis' 'Health Care' ... '2013-06-21' 1555280 '1952']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 503

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 503

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 4024

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# Symbol                   object
# Security                 object
# GICS Sector              object
# GICS Sub-Industry        object
# Headquarters Location    object
# Date added               object
# CIK                       int64
# Founded                  object
# dtype: object

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Symbol', 'Security', 'GICS Sector', 'GICS Sub-Industry',
#        'Headquarters Location', 'Date added', 'CIK', 'Founded'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 CIK
# count  5.030000e+02
# mean   8.217536e+05
# std    5.665200e+05
# min    1.800000e+03
# 25%    1.005050e+05
# 50%    9.000750e+05
# 75%    1.175188e+06
# max    2.005951e+06

# %%
df.median(numeric_only=True)
# Out:
# CIK    900075.0
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# CIK    821753.648111
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#        CIK
# 0  1564708
# 1  1652044
# 2  1754301

# %%
df.std(numeric_only=True)
# Out:
# CIK    566520.030139
# dtype: float64

# %%
df.sample(5)
# Out:
#     Symbol                   Security             GICS Sector  \
# 231    HES           Hess Corporation                  Energy
# 39    AAPL                 Apple Inc.  Information Technology
# 466    UHS  Universal Health Services             Health Care
# 443    TER                   Teradyne  Information Technology
# 202   FTNT                   Fortinet  Information Technology
#
#                               GICS Sub-Industry  \
# 231                        Integrated Oil & Gas
# 39   Technology Hardware, Storage & Peripherals
# 466                      Health Care Facilities
# 443         Semiconductor Materials & Equipment
# 202                            Systems Software
#
#              Headquarters Location  Date added      CIK Founded
# 231        New York City, New York  1984-05-31     4447    1919
# 39           Cupertino, California  1982-11-30   320193    1977
# 466  King of Prussia, Pennsylvania  2014-09-20   352915    1979
# ...

# %%
df.sample(20)
# Out:
#     Symbol                 Security             GICS Sector  \
# 143   DECK           Deckers Brands  Consumer Discretionary
# 339    NWS      News Corp (Class B)  Communication Services
# 434   TMUS              T-Mobile US  Communication Services
# 348    NRG               NRG Energy               Utilities
# 192   FAST                 Fastenal             Industrials
# 131   CSGP             CoStar Group             Real Estate
# 324    MOH        Molina Healthcare             Health Care
# 10     APD             Air Products               Materials
# 290    LLY              Lilly (Eli)             Health Care
# 70    BKNG         Booking Holdings  Consumer Discretionary
# 483    WMT                  Walmart        Consumer Staples
# 79      BG             Bunge Global        Consumer Staples
# 345   NTRS           Northern Trust              Financials
# 499    YUM              Yum! Brands  Consumer Discretionary
# 209     IT                  Gartner  Information Technology
# ...

# %%
df.sample(2)
# Out:
#     Symbol        Security GICS Sector    GICS Sub-Industry  \
# 299    MTB        M&T Bank  Financials       Regional Banks
# 378    PPG  PPG Industries   Materials  Specialty Chemicals
#
#         Headquarters Location  Date added    CIK Founded
# 299         Buffalo, New York  2004-02-23  36270    1856
# 378  Pittsburgh, Pennsylvania  1957-03-04  79879    1883

# %%
# Remove rows with missing values
df.dropna()
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['CIK',
#  'Founded',
#  'Security',
#  'Symbol',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# CIK    784561.1
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# CIK    855004.22
# dtype: float64

# %%
df.columns
# Out:
# Index(['Symbol', 'Security', 'GICS Sector', 'GICS Sub-Industry',
#        'Headquarters Location', 'Date added', 'CIK', 'Founded'],
#       dtype='object')

# %%
df['Symbol']
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     XYL
# 499     YUM
# 500    ZBRA
# 501     ZBH
# 502     ZTS
# Name: Symbol, Length: 503, dtype: object

# %%
df['Security'].describe()
# Out:
# count        503
# unique       503
# top       Zoetis
# freq           1
# Name: Security, dtype: object

# %%
df['Date added'].describe()
# Out:
# count            503
# unique           376
# top       1957-03-04
# freq              54
# Name: Date added, dtype: object

# %%
df['Headquarters Location'].count()
# Out:
# np.int64(503)

# %%
df['Security'].count()
# Out:
# np.int64(503)

# %%
df['CIK'].mean()
# Out:
# np.float64(821753.648111332)

# %%
df['Security'].describe()
# Out:
# count        503
# unique       503
# top       Zoetis
# freq           1
# Name: Security, dtype: object

# %%
df[10:20]
# Out:
#    Symbol                         Security             GICS Sector  \
# 10    APD                     Air Products               Materials
# 11   ABNB                           Airbnb  Consumer Discretionary
# 12   AKAM              Akamai Technologies  Information Technology
# 13    ALB            Albemarle Corporation               Materials
# 14    ARE  Alexandria Real Estate Equities             Real Estate
# 15   ALGN                 Align Technology             Health Care
# 16   ALLE                         Allegion             Industrials
# 17    LNT                   Alliant Energy               Utilities
# 18    ALL                         Allstate              Financials
# 19  GOOGL          Alphabet Inc. (Class A)  Communication Services
#
#                      GICS Sub-Industry      Headquarters Location  Date added  \
# 10                    Industrial Gases    Allentown, Pennsylvania  1985-04-30
# ...

# %%
df[11:30]
# Out:
#    Symbol                         Security             GICS Sector  \
# 11   ABNB                           Airbnb  Consumer Discretionary
# 12   AKAM              Akamai Technologies  Information Technology
# 13    ALB            Albemarle Corporation               Materials
# 14    ARE  Alexandria Real Estate Equities             Real Estate
# 15   ALGN                 Align Technology             Health Care
# 16   ALLE                         Allegion             Industrials
# 17    LNT                   Alliant Energy               Utilities
# 18    ALL                         Allstate              Financials
# 19  GOOGL          Alphabet Inc. (Class A)  Communication Services
# 20   GOOG          Alphabet Inc. (Class C)  Communication Services
# 21     MO                           Altria        Consumer Staples
# 22   AMZN                           Amazon  Consumer Discretionary
# 23   AMCR                            Amcor               Materials
# ...

# %%
df.loc[10:20,['Symbol', 'Security', 'GICS Sector']]
# Out:
#    Symbol                         Security             GICS Sector
# 10    APD                     Air Products               Materials
# 11   ABNB                           Airbnb  Consumer Discretionary
# 12   AKAM              Akamai Technologies  Information Technology
# 13    ALB            Albemarle Corporation               Materials
# 14    ARE  Alexandria Real Estate Equities             Real Estate
# 15   ALGN                 Align Technology             Health Care
# 16   ALLE                         Allegion             Industrials
# 17    LNT                   Alliant Energy               Utilities
# 18    ALL                         Allstate              Financials
# 19  GOOGL          Alphabet Inc. (Class A)  Communication Services
# 20   GOOG          Alphabet Inc. (Class C)  Communication Services

# %%
df.loc[34:40,[ 'Date added', 'CIK', 'Founded']]
# Out:
#     Date added      CIK      Founded
# 34  2008-09-30   820313         1932
# 35  1999-10-12     6281         1965
# 36  2017-06-19  1013462         1969
# 37  1996-04-23   315293  1982 (1919)
# 38  1997-07-28  1841666         1954
# 39  1982-11-30   320193         1977
# 40  1995-03-16     6951         1967

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
df.min(numeric_only=True)
# Out:
# CIK    1800
# dtype: int64

# %%
df.max(numeric_only=True)
# Out:
# CIK    2005951
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 503 non-null    object
#  1   Security               503 non-null    object
#  2   GICS Sector            503 non-null    object
#  3   GICS Sub-Industry      503 non-null    object
#  4   Headquarters Location  503 non-null    object
#  5   Date added             503 non-null    object
#  6   CIK                    503 non-null    int64
#  7   Founded                503 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 31.6+ KB
