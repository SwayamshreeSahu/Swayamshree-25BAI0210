# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/BEPS.csv")

# %%
df.head()
# Out:
#    rownames              vote  age  economic.cond.national  \
# 0         1  Liberal Democrat   43                       3
# 1         2            Labour   36                       4
# 2         3            Labour   35                       4
# 3         4            Labour   24                       4
# 4         5            Labour   41                       2
#
#    economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                        3      4      1        4       2
# 1                        4      4      4        4       5
# 2                        4      5      2        3       3
# 3                        2      2      1        3       4
# 4                        2      1      1        4       6
#
#    political.knowledge  gender
# 0                    2  female
# 1                    2    male
# 2                    2    male
# 3                    0  female
# 4                    2    male

# %%
df.head(10)
# Out:
#    rownames              vote  age  economic.cond.national  \
# 0         1  Liberal Democrat   43                       3
# 1         2            Labour   36                       4
# 2         3            Labour   35                       4
# 3         4            Labour   24                       4
# 4         5            Labour   41                       2
# 5         6            Labour   47                       3
# 6         7  Liberal Democrat   57                       2
# 7         8            Labour   77                       3
# 8         9            Labour   39                       3
# 9        10            Labour   70                       3
#
#    economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                        3      4      1        4       2
# 1                        4      4      4        4       5
# 2                        4      5      2        3       3
# 3                        2      2      1        3       4
# ...

# %%
df.head(20)
# Out:
#     rownames              vote  age  economic.cond.national  \
# 0          1  Liberal Democrat   43                       3
# 1          2            Labour   36                       4
# 2          3            Labour   35                       4
# 3          4            Labour   24                       4
# 4          5            Labour   41                       2
# 5          6            Labour   47                       3
# 6          7  Liberal Democrat   57                       2
# 7          8            Labour   77                       3
# 8          9            Labour   39                       3
# 9         10            Labour   70                       3
# 10        11            Labour   39                       3
# 11        12            Labour   66                       4
# 12        13            Labour   59                       4
# 13        14            Labour   66                       3
# 14        15            Labour   77                       2
# ...

# %%
df.tail()
# Out:
#       rownames          vote  age  economic.cond.national  \
# 1520      1521  Conservative   67                       5
# 1521      1522  Conservative   73                       2
# 1522      1523        Labour   37                       3
# 1523      1524  Conservative   61                       3
# 1524      1525  Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 1520                        3      2      4        4      11
# 1521                        2      4      4        4       8
# 1522                        3      5      4        4       2
# 1523                        3      1      4        1      11
# 1524                        3      2      4        4      11
#
#       political.knowledge  gender
# 1520                    3    male
# 1521                    2    male
# 1522                    2    male
# 1523                    2    male
# 1524                    0  female

# %%
df.tail(6)
# Out:
#       rownames          vote  age  economic.cond.national  \
# 1519      1520  Conservative   35                       3
# 1520      1521  Conservative   67                       5
# 1521      1522  Conservative   73                       2
# 1522      1523        Labour   37                       3
# 1523      1524  Conservative   61                       3
# 1524      1525  Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 1519                        4      4      2        4       8
# 1520                        3      2      4        4      11
# 1521                        2      4      4        4       8
# 1522                        3      5      4        4       2
# 1523                        3      1      4        1      11
# 1524                        3      2      4        4      11
#
#       political.knowledge  gender
# 1519                    2    male
# 1520                    3    male
# ...

# %%
df.min(numeric_only=True)
# Out:
# rownames                    1
# age                        24
# economic.cond.national      1
# economic.cond.household     1
# Blair                       1
# Hague                       1
# Kennedy                     1
# Europe                      1
# political.knowledge         0
# dtype: int64

# %%
df.max(numeric_only=True)
# Out:
# rownames                   1525
# age                          93
# economic.cond.national        5
# economic.cond.household       5
# Blair                         5
# Hague                         5
# Kennedy                       5
# Europe                       11
# political.knowledge           3
# dtype: int64

# %%
df.dtypes
# Out:
# rownames                    int64
# vote                       object
# age                         int64
# economic.cond.national      int64
# economic.cond.household     int64
# Blair                       int64
# Hague                       int64
# Kennedy                     int64
# Europe                      int64
# political.knowledge         int64
# gender                     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   rownames                 1525 non-null   int64
#  1   vote                     1525 non-null   object
#  2   age                      1525 non-null   int64
#  3   economic.cond.national   1525 non-null   int64
#  4   economic.cond.household  1525 non-null   int64
#  5   Blair                    1525 non-null   int64
#  6   Hague                    1525 non-null   int64
#  7   Kennedy                  1525 non-null   int64
#  8   Europe                   1525 non-null   int64
#  9   political.knowledge      1525 non-null   int64
#  10  gender                   1525 non-null   object
# dtypes: int64(9), object(2)
# memory usage: 131.2+ KB

# %%
df['age'].dtypes
# Out:
# dtype('int64')

# %%
df['economic.cond.national'].dtypes
# Out:
# dtype('int64')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=1525, step=1), Index(['rownames', 'vote', 'age', 'economic.cond.national',
#        'economic.cond.household', 'Blair', 'Hague', 'Kennedy', 'Europe',
#        'political.knowledge', 'gender'],
#       dtype='object')]

# %%
print(df.size)
# Out:
# 16775

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.shape)
# Out:
# (1525, 11)

# %%
print(df.values)
# Out:
# [[1 'Liberal Democrat' 43 ... 2 2 'female']
#  [2 'Labour' 36 ... 5 2 'male']
#  [3 'Labour' 35 ... 3 2 'male']
#  ...
#  [1523 'Labour' 37 ... 2 2 'male']
#  [1524 'Conservative' 61 ... 11 2 'male']
#  [1525 'Conservative' 74 ... 11 0 'female']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 1525

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 1525

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 16775

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['rownames', 'vote', 'age', 'economic.cond.national',
#        'economic.cond.household', 'Blair', 'Hague', 'Kennedy', 'Europe',
#        'political.knowledge', 'gender'],
#       dtype='object')

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# rownames                    int64
# vote                       object
# age                         int64
# economic.cond.national      int64
# economic.cond.household     int64
# Blair                       int64
# Hague                       int64
# Kennedy                     int64
# Europe                      int64
# political.knowledge         int64
# gender                     object
# dtype: object

# %%
df.describe()
# Out:
#           rownames          age  economic.cond.national  \
# count  1525.000000  1525.000000             1525.000000
# mean    763.000000    54.182295                3.245902
# std     440.373894    15.711209                0.880969
# min       1.000000    24.000000                1.000000
# 25%     382.000000    41.000000                3.000000
# 50%     763.000000    53.000000                3.000000
# 75%    1144.000000    67.000000                4.000000
# max    1525.000000    93.000000                5.000000
#
#        economic.cond.household        Blair        Hague      Kennedy  \
# count              1525.000000  1525.000000  1525.000000  1525.000000
# mean                  3.140328     3.334426     2.746885     3.135082
# std                   0.929951     1.174824     1.230703     1.081997
# min                   1.000000     1.000000     1.000000     1.000000
# 25%                   3.000000     2.000000     2.000000     2.000000
# ...

# %%
df.median(numeric_only=True)
# Out:
# rownames                   763.0
# age                         53.0
# economic.cond.national       3.0
# economic.cond.household      3.0
# Blair                        4.0
# Hague                        2.0
# Kennedy                      3.0
# Europe                       6.0
# political.knowledge          2.0
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# rownames                   763.000000
# age                         54.182295
# economic.cond.national       3.245902
# economic.cond.household      3.140328
# Blair                        3.334426
# Hague                        2.746885
# Kennedy                      3.135082
# Europe                       6.728525
# political.knowledge          1.542295
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#       rownames   age  economic.cond.national  economic.cond.household  Blair  \
# 0            1  37.0                     3.0                      3.0    4.0
# 1            2   NaN                     NaN                      NaN    NaN
# 2            3   NaN                     NaN                      NaN    NaN
# 3            4   NaN                     NaN                      NaN    NaN
# 4            5   NaN                     NaN                      NaN    NaN
# ...        ...   ...                     ...                      ...    ...
# 1520      1521   NaN                     NaN                      NaN    NaN
# 1521      1522   NaN                     NaN                      NaN    NaN
# 1522      1523   NaN                     NaN                      NaN    NaN
# 1523      1524   NaN                     NaN                      NaN    NaN
# 1524      1525   NaN                     NaN                      NaN    NaN
#
# ...

# %%
df.std(numeric_only=True)
# Out:
# rownames                   440.373894
# age                         15.711209
# economic.cond.national       0.880969
# economic.cond.household      0.929951
# Blair                        1.174824
# Hague                        1.230703
# Kennedy                      1.081997
# Europe                       3.297538
# political.knowledge          1.083315
# dtype: float64

# %%
df.sample(5)
# Out:
#       rownames          vote  age  economic.cond.national  \
# 688        689  Conservative   50                       2
# 277        278  Conservative   63                       2
# 1095      1096        Labour   40                       4
# 432        433        Labour   65                       4
# 455        456        Labour   70                       5
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 688                         4      2      5        4      11
# 277                         4      2      4        2      10
# 1095                        4      4      2        2       2
# 432                         3      4      4        4       1
# 455                         4      4      2        4       6
#
#       political.knowledge  gender
# 688                     2  female
# 277                     3  female
# 1095                    2  female
# 432                     3  female
# 455                     3  female

# %%
df.sample(20)
# Out:
#       rownames              vote  age  economic.cond.national  \
# 1167      1168      Conservative   24                       4
# 1375      1376            Labour   50                       4
# 306        307      Conservative   70                       2
# 777        778            Labour   60                       5
# 696        697            Labour   78                       5
# 1131      1132            Labour   36                       3
# 377        378      Conservative   29                       4
# 40          41            Labour   42                       4
# 807        808            Labour   77                       4
# 1473      1474            Labour   54                       3
# 1498      1499            Labour   65                       3
# 1449      1450  Liberal Democrat   47                       4
# 103        104      Conservative   70                       2
# 525        526            Labour   32                       4
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#       rownames              vote  age  economic.cond.national  \
# 0            1  Liberal Democrat   43                       3
# 1            2            Labour   36                       4
# 2            3            Labour   35                       4
# 3            4            Labour   24                       4
# 4            5            Labour   41                       2
# ...        ...               ...  ...                     ...
# 1520      1521      Conservative   67                       5
# 1521      1522      Conservative   73                       2
# 1522      1523            Labour   37                       3
# 1523      1524      Conservative   61                       3
# 1524      1525      Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                           3      4      1        4       2
# 1                           4      4      4        4       5
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['Blair',
#  'Europe',
#  'Hague',
#  'Kennedy',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# rownames                   25.50
# age                        52.22
# economic.cond.national      3.00
# economic.cond.household     2.82
# Blair                       3.44
# Hague                       2.70
# Kennedy                     3.04
# Europe                      5.56
# political.knowledge         1.42
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# rownames                   1500.50
# age                          58.40
# economic.cond.national        3.10
# economic.cond.household       2.72
# Blair                         3.36
# Hague                         2.82
# Kennedy                       3.20
# Europe                        6.56
# political.knowledge           1.80
# dtype: float64

# %%
df.columns
# Out:
# Index(['rownames', 'vote', 'age', 'economic.cond.national',
#        'economic.cond.household', 'Blair', 'Hague', 'Kennedy', 'Europe',
#        'political.knowledge', 'gender'],
#       dtype='object')

# %%
df['age']
# Out:
# 0       43
# 1       36
# 2       35
# 3       24
# 4       41
#         ..
# 1520    67
# 1521    73
# 1522    37
# 1523    61
# 1524    74
# Name: age, Length: 1525, dtype: int64

# %%
df['vote'].describe()
# Out:
# count       1525
# unique         3
# top       Labour
# freq         720
# Name: vote, dtype: object

# %%
df['economic.cond.household'].describe()
# Out:
# count    1525.000000
# mean        3.140328
# std         0.929951
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: economic.cond.household, dtype: float64

# %%
df['Blair'].count()
# Out:
# np.int64(1525)

# %%
df['Europe'].count()
# Out:
# np.int64(1525)

# %%
df['rownames'].mean()
# Out:
# np.float64(763.0)

# %%
df['age'].mean()
# Out:
# np.float64(54.18229508196721)

# %%
df[10:30]
# Out:
#     rownames              vote  age  economic.cond.national  \
# 10        11            Labour   39                       3
# 11        12            Labour   66                       4
# 12        13            Labour   59                       4
# 13        14            Labour   66                       3
# 14        15            Labour   77                       2
# 15        16            Labour   51                       4
# 16        17            Labour   43                       2
# 17        18            Labour   41                       4
# 18        19            Labour   79                       3
# 19        20            Labour   37                       3
# 20        21            Labour   38                       3
# 21        22  Liberal Democrat   53                       2
# 22        23            Labour   59                       3
# 23        24      Conservative   44                       2
# 24        25      Conservative   60                       3
# ...

# %%
df[10:20]
# Out:
#     rownames    vote  age  economic.cond.national  economic.cond.household  \
# 10        11  Labour   39                       3                        3
# 11        12  Labour   66                       4                        3
# 12        13  Labour   59                       4                        4
# 13        14  Labour   66                       3                        3
# 14        15  Labour   77                       2                        3
# 15        16  Labour   51                       4                        4
# 16        17  Labour   43                       2                        4
# 17        18  Labour   41                       4                        4
# 18        19  Labour   79                       3                        3
# 19        20  Labour   37                       3                        1
#
#     Blair  Hague  Kennedy  Europe  political.knowledge  gender
# 10      1      2        1       7                    0  female
# ...

# %%
df.loc[10:20,['rownames', 'vote', 'age', 'economic.cond.national']]
# Out:
#     rownames    vote  age  economic.cond.national
# 10        11  Labour   39                       3
# 11        12  Labour   66                       4
# 12        13  Labour   59                       4
# 13        14  Labour   66                       3
# 14        15  Labour   77                       2
# 15        16  Labour   51                       4
# 16        17  Labour   43                       2
# 17        18  Labour   41                       4
# 18        19  Labour   79                       3
# 19        20  Labour   37                       3
# 20        21  Labour   38                       3

# %%
df.loc[10:20,['political.knowledge', 'gender']]
# Out:
#     political.knowledge  gender
# 10                    0  female
# 11                    2    male
# 12                    2  female
# 13                    0  female
# 14                    2  female
# 15                    0    male
# 16                    0  female
# 17                    2  female
# 18                    0    male
# 19                    2  female
# 20                    0    male

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#       rownames              vote  age  economic.cond.national  \
# 0            1  Liberal Democrat   43                       3
# 1            2            Labour   36                       4
# 2            3            Labour   35                       4
# 3            4            Labour   24                       4
# 4            5            Labour   41                       2
# ...        ...               ...  ...                     ...
# 1520      1521      Conservative   67                       5
# 1521      1522      Conservative   73                       2
# 1522      1523            Labour   37                       3
# 1523      1524      Conservative   61                       3
# 1524      1525      Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                           3      4      1        4       2
# 1                           4      4      4        4       5
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#       rownames              vote  age  economic.cond.national  \
# 0            1  Liberal Democrat   43                       3
# 1            2            Labour   36                       4
# 2            3            Labour   35                       4
# 3            4            Labour   24                       4
# 4            5            Labour   41                       2
# ...        ...               ...  ...                     ...
# 1520      1521      Conservative   67                       5
# 1521      1522      Conservative   73                       2
# 1522      1523            Labour   37                       3
# 1523      1524      Conservative   61                       3
# 1524      1525      Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                           3      4      1        4       2
# 1                           4      4      4        4       5
# ...

# %%
df.min()
# Out:
# rownames                              1
# vote                       Conservative
# age                                  24
# economic.cond.national                1
# economic.cond.household               1
# Blair                                 1
# Hague                                 1
# Kennedy                               1
# Europe                                1
# political.knowledge                   0
# gender                           female
# dtype: object

# %%
df.max()
# Out:
# rownames                               1525
# vote                       Liberal Democrat
# age                                      93
# economic.cond.national                    5
# economic.cond.household                   5
# Blair                                     5
# Hague                                     5
# Kennedy                                   5
# Europe                                   11
# political.knowledge                       3
# gender                                 male
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   rownames                 1525 non-null   int64
#  1   vote                     1525 non-null   object
#  2   age                      1525 non-null   int64
#  3   economic.cond.national   1525 non-null   int64
#  4   economic.cond.household  1525 non-null   int64
#  5   Blair                    1525 non-null   int64
#  6   Hague                    1525 non-null   int64
#  7   Kennedy                  1525 non-null   int64
#  8   Europe                   1525 non-null   int64
#  9   political.knowledge      1525 non-null   int64
#  10  gender                   1525 non-null   object
# dtypes: int64(9), object(2)
# memory usage: 131.2+ KB
