# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_excel("/content/Coffee Shop Sales.xlsx")

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# ...

# %%
df.head(10)
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
# 5               6       2023-01-01         07:22:41                1
# 6               7       2023-01-01         07:25:49                1
# 7               8       2023-01-01         07:33:34                2
# 8               9       2023-01-01         07:39:13                1
# 9              10       2023-01-01         07:39:34                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32        3.00              Coffee
# ...

# %%
df.head(20)
# Out:
#     transaction_id transaction_date transaction_time  transaction_qty  \
# 0                1       2023-01-01         07:06:11                2
# 1                2       2023-01-01         07:08:56                2
# 2                3       2023-01-01         07:14:04                2
# 3                4       2023-01-01         07:20:24                1
# 4                5       2023-01-01         07:22:41                2
# 5                6       2023-01-01         07:22:41                1
# 6                7       2023-01-01         07:25:49                1
# 7                8       2023-01-01         07:33:34                2
# 8                9       2023-01-01         07:39:13                1
# 9               10       2023-01-01         07:39:34                2
# 10              11       2023-01-01         07:43:05                1
# 11              12       2023-01-01         07:44:35                2
# ...

# %%
df.tail()
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  store_location  product_id  unit_price product_category  \
# 149111         8  Hell's Kitchen          44        2.50              Tea
# 149112         8  Hell's Kitchen          49        3.00              Tea
# 149113         8  Hell's Kitchen          45        3.00              Tea
# 149114         8  Hell's Kitchen          40        3.75           Coffee
# 149115         8  Hell's Kitchen          64        0.80         Flavours
#
#              product_type        product_detail
# ...

# %%
df.tail(12)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 149104          149445       2023-06-30         19:52:28                2
# 149105          149446       2023-06-30         19:53:46                1
# 149106          149447       2023-06-30         19:56:45                1
# 149107          149448       2023-06-30         19:57:49                2
# 149108          149449       2023-06-30         19:57:49                1
# 149109          149450       2023-06-30         20:08:38                2
# 149110          149451       2023-06-30         20:16:31                2
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
# ...

# %%
df.min(numeric_only=True)
# Out:
# transaction_id     1.0
# transaction_qty    1.0
# store_id           3.0
# product_id         1.0
# unit_price         0.8
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# transaction_id     149456.0
# transaction_qty         8.0
# store_id                8.0
# product_id             87.0
# unit_price             45.0
# dtype: float64

# %%
df.dtypes
# Out:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                   int64
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB

# %%
df['product_id'].dtypes
# Out:
# dtype('int64')

# %%
df['product_type'].dtypes
# Out:
# dtype('O')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=149116, step=1), Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 1640276

# %%
print(df.shape)
# Out:
# (149116, 11)

# %%
print(df.values)
# Out:
# [[1 Timestamp('2023-01-01 00:00:00') datetime.time(7, 6, 11) ... 'Coffee'
#   'Gourmet brewed coffee' 'Ethiopia Rg']
#  [2 Timestamp('2023-01-01 00:00:00') datetime.time(7, 8, 56) ... 'Tea'
#   'Brewed Chai tea' 'Spicy Eye Opener Chai Lg']
#  [3 Timestamp('2023-01-01 00:00:00') datetime.time(7, 14, 4) ...
#   'Drinking Chocolate' 'Hot chocolate' 'Dark chocolate Lg']
#  ...
#  [149454 Timestamp('2023-06-30 00:00:00') datetime.time(20, 31, 34) ...
#   'Tea' 'Brewed herbal tea' 'Peppermint Lg']
#  [149455 Timestamp('2023-06-30 00:00:00') datetime.time(20, 57, 19) ...
#   'Coffee' 'Barista Espresso' 'Cappuccino']
#  [149456 Timestamp('2023-06-30 00:00:00') datetime.time(20, 57, 19) ...
#   'Flavours' 'Regular syrup' 'Hazelnut syrup']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 149116

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 149116

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 1640276

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                   int64
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# dtype: object

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail'],
#       dtype='object')

# %%
df.describe()
# Out:
#        transaction_id               transaction_date  transaction_qty  \
# count   149116.000000                         149116    149116.000000
# mean     74737.371872  2023-04-15 11:50:32.173609984         1.438276
# min          1.000000            2023-01-01 00:00:00         1.000000
# 25%      37335.750000            2023-03-06 00:00:00         1.000000
# 50%      74727.500000            2023-04-24 00:00:00         1.000000
# 75%     112094.250000            2023-05-30 00:00:00         2.000000
# max     149456.000000            2023-06-30 00:00:00         8.000000
# std      43153.600016                            NaN         0.542509
#
#             store_id     product_id     unit_price
# count  149116.000000  149116.000000  149116.000000
# mean        5.342063      47.918607       3.382219
# min         3.000000       1.000000       0.800000
# 25%         3.000000      33.000000       2.500000
# 50%         5.000000      47.000000       3.000000
# ...

# %%
df.median(numeric_only=True)
# Out:
# transaction_id     74727.5
# transaction_qty        1.0
# store_id               5.0
# product_id            47.0
# unit_price             3.0
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# transaction_id     74737.371872
# transaction_qty        1.438276
# store_id               5.342063
# product_id            47.918607
# unit_price             3.382219
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#         transaction_id  transaction_qty  store_id  product_id  unit_price
# 0                    1              1.0       8.0        71.0         3.0
# 1                    2              NaN       NaN         NaN         NaN
# 2                    3              NaN       NaN         NaN         NaN
# 3                    4              NaN       NaN         NaN         NaN
# 4                    5              NaN       NaN         NaN         NaN
# ...                ...              ...       ...         ...         ...
# 149111          149452              NaN       NaN         NaN         NaN
# 149112          149453              NaN       NaN         NaN         NaN
# 149113          149454              NaN       NaN         NaN         NaN
# 149114          149455              NaN       NaN         NaN         NaN
# 149115          149456              NaN       NaN         NaN         NaN
#
# [149116 rows x 5 columns]

# %%
df.std(numeric_only=True)
# Out:
# transaction_id     43153.600016
# transaction_qty        0.542509
# store_id               2.074241
# product_id            17.930020
# unit_price             2.658723
# dtype: float64

# %%
df.sample(5)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 41609            41716       2023-03-12         14:01:03                2
# 46805            46912       2023-03-19         17:59:38                1
# 91952            92206       2023-05-11         19:26:08                1
# 147347          147684       2023-06-29         11:41:17                2
# 40208            40315       2023-03-10         12:57:26                2
#
#         store_id   store_location  product_id  unit_price product_category  \
# 41609          8   Hell's Kitchen          39        4.25           Coffee
# 46805          5  Lower Manhattan          42        2.50              Tea
# 91952          3          Astoria          26        3.00           Coffee
# 147347         5  Lower Manhattan          87        2.10           Coffee
# 40208          8   Hell's Kitchen          49        3.00              Tea
#
#                  product_type        product_detail
# ...

# %%
df.sample(20)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 144815          145152       2023-06-27         08:20:25                1
# 11980            12010       2023-01-21         18:17:40                2
# 147622          147959       2023-06-29         14:58:36                2
# 13466            13496       2023-01-24         13:00:19                1
# 85196            85370       2023-05-05         16:36:18                1
# 62153            62323       2023-04-09         17:46:14                1
# 110527          110781       2023-05-28         15:42:13                2
# 73411            73581       2023-04-22         16:48:24                1
# 21834            21891       2023-02-09         07:52:18                1
# 43271            43378       2023-03-15         07:10:05                2
# 112180          112438       2023-05-30         09:46:33                2
# 49684            49791       2023-03-24         07:32:54                2
# ...

# %%
df.sample(2)
# Out:
#        transaction_id transaction_date transaction_time  transaction_qty  \
# 36806           36863       2023-03-05         16:15:49                2
# 18892           18922       2023-02-03         17:16:31                1
#
#        store_id  store_location  product_id  unit_price    product_category  \
# 36806         8  Hell's Kitchen          22         2.0              Coffee
# 18892         3         Astoria          58         3.5  Drinking Chocolate
#
#         product_type               product_detail
# 36806    Drip coffee  Our Old Time Diner Blend Sm
# 18892  Hot chocolate            Dark chocolate Rg

# %%
df.sample(13)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 79900            80074       2023-04-30         10:59:43                1
# 102945          103199       2023-05-21         13:51:52                2
# 90218            90472       2023-05-10         09:35:35                1
# 89837            90091       2023-05-10         07:05:20                1
# 60926            61096       2023-04-08         11:17:35                1
# 76848            77018       2023-04-26         15:53:53                2
# 69822            69992       2023-04-18         11:23:03                1
# 20393            20423       2023-02-06         14:57:17                1
# 7876              7906       2023-01-15         07:22:05                1
# 113658          113920       2023-05-31         17:21:48                2
# 29584            29641       2023-02-22         06:02:09                3
# 19733            19763       2023-02-05         11:12:16                2
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# transaction_id     25.500
# transaction_qty     1.400
# store_id            5.900
# product_id         48.980
# unit_price          3.161
# dtype: float64

# %%
print("Mean values of the last 30 records:")
print(df.tail(30).mean(numeric_only=True))
# Out:
# Mean values of the last 30 records:
# transaction_id     149441.500000
# transaction_qty         1.500000
# store_id                5.466667
# product_id             44.766667
# unit_price              3.598333
# dtype: float64

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail'],
#       dtype='object')

# %%
df['transaction_date']
# Out:
# 0        2023-01-01
# 1        2023-01-01
# 2        2023-01-01
# 3        2023-01-01
# 4        2023-01-01
#             ...
# 149111   2023-06-30
# 149112   2023-06-30
# 149113   2023-06-30
# 149114   2023-06-30
# 149115   2023-06-30
# Name: transaction_date, Length: 149116, dtype: datetime64[ns]

# %%
df['transaction_qty'].describe()
# Out:
# count    149116.000000
# mean          1.438276
# std           0.542509
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           8.000000
# Name: transaction_qty, dtype: float64

# %%
df['unit_price'].describe()
# Out:
# count    149116.000000
# mean          3.382219
# std           2.658723
# min           0.800000
# 25%           2.500000
# 50%           3.000000
# 75%           3.750000
# max          45.000000
# Name: unit_price, dtype: float64

# %%
df['product_category'].count()
# Out:
# np.int64(149116)

# %%
df['product_type'].count()
# Out:
# np.int64(149116)

# %%
df['transaction_time'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1338/3711351409.py in <cell line: 0>()
# ----> 1 df['transaction_time'].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
df['unit_price'].describe()
# Out:
# count    149116.000000
# mean          3.382219
# std           2.658723
# min           0.800000
# 25%           2.500000
# 50%           3.000000
# 75%           3.750000
# max          45.000000
# Name: unit_price, dtype: float64

# %%
df[10:20]
# Out:
#     transaction_id transaction_date transaction_time  transaction_qty  \
# 10              11       2023-01-01         07:43:05                1
# 11              12       2023-01-01         07:44:35                2
# 12              13       2023-01-01         07:45:51                1
# 13              14       2023-01-01         07:48:19                1
# 14              15       2023-01-01         07:52:36                2
# 15              16       2023-01-01         07:59:58                2
# 16              17       2023-01-01         07:59:58                1
# 17              18       2023-01-01         08:00:18                1
# 18              19       2023-01-01         08:00:39                2
# 19              20       2023-01-01         08:11:45                1
#
#     store_id   store_location  product_id  unit_price    product_category  \
# 10         5  Lower Manhattan          56        2.55                 Tea
# ...

# %%
df[11:30]
# Out:
#     transaction_id transaction_date transaction_time  transaction_qty  \
# 11              12       2023-01-01         07:44:35                2
# 12              13       2023-01-01         07:45:51                1
# 13              14       2023-01-01         07:48:19                1
# 14              15       2023-01-01         07:52:36                2
# 15              16       2023-01-01         07:59:58                2
# 16              17       2023-01-01         07:59:58                1
# 17              18       2023-01-01         08:00:18                1
# 18              19       2023-01-01         08:00:39                2
# 19              20       2023-01-01         08:11:45                1
# 20              21       2023-01-01         08:17:27                2
# 21              22       2023-01-01         08:24:26                2
# 22              23       2023-01-01         08:24:26                1
# ...

# %%
df.loc[10:20,['transaction_id', 'transaction_date']]
# Out:
#     transaction_id transaction_date
# 10              11       2023-01-01
# 11              12       2023-01-01
# 12              13       2023-01-01
# 13              14       2023-01-01
# 14              15       2023-01-01
# 15              16       2023-01-01
# 16              17       2023-01-01
# 17              18       2023-01-01
# 18              19       2023-01-01
# 19              20       2023-01-01
# 20              21       2023-01-01

# %%
df.loc[34:40,['unit_price', 'product_category']]
# Out:
#     unit_price product_category
# 34        2.50              Tea
# 35        3.00           Coffee
# 36        4.00              Tea
# 37        3.75           Coffee
# 38        3.00              Tea
# 39        3.00              Tea
# 40        3.00           Coffee

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.min(numeric_only=True)
# Out:
# transaction_id     1.0
# transaction_qty    1.0
# store_id           3.0
# product_id         1.0
# unit_price         0.8
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# transaction_id     149456.0
# transaction_qty         8.0
# store_id                8.0
# product_id             87.0
# unit_price             45.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB
