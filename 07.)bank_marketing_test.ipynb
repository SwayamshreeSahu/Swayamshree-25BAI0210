# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/bank_marketing_test.csv")

# %%
df.head()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   56     services  married  high.school       no      no  yes  telephone
# 1   41  blue-collar  married      unknown  unknown      no   no  telephone
# 2   25     services   single  high.school       no     yes   no  telephone
# 3   35  blue-collar  married     basic.6y       no     yes   no  telephone
# 4   46  blue-collar  married     basic.6y  unknown     yes  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56     services  married          high.school       no      no  yes
# 1   41  blue-collar  married              unknown  unknown      no   no
# 2   25     services   single          high.school       no     yes   no
# 3   35  blue-collar  married             basic.6y       no     yes   no
# 4   46  blue-collar  married             basic.6y  unknown     yes  yes
# 5   55      unknown  married             basic.4y  unknown     yes   no
# 6   56   technician  married             basic.4y       no     yes   no
# 7   40  blue-collar  married             basic.9y       no      no  yes
# 8   45  blue-collar  married             basic.9y       no     yes   no
# 9   53       admin.   single  professional.course       no      no   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
df.head(20)
# Out:
#     age          job  marital            education  default  housing     loan  \
# 0    56     services  married          high.school       no       no      yes
# 1    41  blue-collar  married              unknown  unknown       no       no
# 2    25     services   single          high.school       no      yes       no
# 3    35  blue-collar  married             basic.6y       no      yes       no
# 4    46  blue-collar  married             basic.6y  unknown      yes      yes
# 5    55      unknown  married             basic.4y  unknown      yes       no
# 6    56   technician  married             basic.4y       no      yes       no
# 7    40  blue-collar  married             basic.9y       no       no      yes
# 8    45  blue-collar  married             basic.9y       no      yes       no
# 9    53       admin.   single  professional.course       no       no       no
# 10   55   technician  married  professional.course  unknown      yes       no
# ...

# %%
df.tail()
# Out:
#       age          job  marital          education default housing loan  \
# 8232   41  blue-collar  married           basic.9y      no     yes   no
# 8233   60  blue-collar  married           basic.4y      no     yes   no
# 8234   32       admin.  married  university.degree      no      no   no
# 8235   32       admin.  married  university.degree      no     yes   no
# 8236   36       admin.  married  university.degree      no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 8232   cellular   nov         mon  ...         2    999         1
# 8233   cellular   nov         tue  ...         2      4         1
# 8234  telephone   nov         wed  ...         1    999         1
# 8235   cellular   nov         wed  ...         3    999         0
# 8236   cellular   nov         fri  ...         2    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.tail(5)
# Out:
#       age          job  marital          education default housing loan  \
# 8232   41  blue-collar  married           basic.9y      no     yes   no
# 8233   60  blue-collar  married           basic.4y      no     yes   no
# 8234   32       admin.  married  university.degree      no      no   no
# 8235   32       admin.  married  university.degree      no     yes   no
# 8236   36       admin.  married  university.degree      no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 8232   cellular   nov         mon  ...         2    999         1
# 8233   cellular   nov         tue  ...         2      4         1
# 8234  telephone   nov         wed  ...         1    999         1
# 8235   cellular   nov         wed  ...         3    999         0
# 8236   cellular   nov         fri  ...         2    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.tail(10)
# Out:
#       age          job   marital            education default housing loan  \
# 8227   58   unemployed   married    university.degree      no     yes   no
# 8228   33   management   married    university.degree      no     yes   no
# 8229   43       admin.  divorced    university.degree      no     yes   no
# 8230   35       admin.    single  professional.course      no     yes   no
# 8231   35       admin.    single  professional.course      no     yes   no
# 8232   41  blue-collar   married             basic.9y      no     yes   no
# 8233   60  blue-collar   married             basic.4y      no     yes   no
# 8234   32       admin.   married    university.degree      no      no   no
# 8235   32       admin.   married    university.degree      no     yes   no
# 8236   36       admin.   married    university.degree      no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 8227   cellular   nov         thu  ...         2    999         0
# ...

# %%
df.min(numeric_only=True)
# Out:
# age                 17.000
# duration             4.000
# campaign             1.000
# pdays                0.000
# previous             0.000
# emp.var.rate        -3.400
# cons.price.idx      92.201
# cons.conf.idx      -50.800
# euribor3m            0.634
# nr.employed       4963.600
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# age                 89.000
# duration          4918.000
# campaign            43.000
# pdays              999.000
# previous             6.000
# emp.var.rate         1.400
# cons.price.idx      94.767
# cons.conf.idx      -26.900
# euribor3m            5.000
# nr.employed       5228.100
# dtype: float64

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8237 entries, 0 to 8236
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8237 non-null   int64
#  1   job             8237 non-null   object
#  2   marital         8237 non-null   object
#  3   education       8237 non-null   object
#  4   default         8237 non-null   object
#  5   housing         8237 non-null   object
#  6   loan            8237 non-null   object
#  7   contact         8237 non-null   object
#  8   month           8237 non-null   object
#  9   day_of_week     8237 non-null   object
#  10  duration        8237 non-null   int64
#  11  campaign        8237 non-null   int64
#  12  pdays           8237 non-null   int64
#  13  previous        8237 non-null   int64
#  14  poutcome        8237 non-null   object
#  15  emp.var.rate    8237 non-null   float64
#  16  cons.price.idx  8237 non-null   float64
# ...

# %%
df['job'].dtypes
# Out:
# dtype('O')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=8237, step=1), Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 172977

# %%
print(df.shape)
# Out:
# (8237, 21)

# %%
print(df.values)
# Out:
# [[56 'services' 'married' ... 4.857 5191.0 'no']
#  [41 'blue-collar' 'married' ... 4.857 5191.0 'no']
#  [25 'services' 'single' ... 4.857 5191.0 'no']
#  ...
#  [32 'admin.' 'married' ... 1.03 4963.6 'yes']
#  [32 'admin.' 'married' ... 1.03 4963.6 'no']
#  [36 'admin.' 'married' ... 1.028 4963.6 'no']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 8237

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 8237

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 172977

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.describe()
# Out:
#                age     duration    campaign        pdays     previous  \
# count  8237.000000  8237.000000  8237.00000  8237.000000  8237.000000
# mean     40.116547   256.007648     2.60471   962.228724     0.174335
# std      10.465328   259.728737     2.91562   187.533881     0.500565
# min      17.000000     4.000000     1.00000     0.000000     0.000000
# 25%      32.000000   101.000000     1.00000   999.000000     0.000000
# 50%      38.000000   179.000000     2.00000   999.000000     0.000000
# 75%      47.000000   316.000000     3.00000   999.000000     0.000000
# max      89.000000  4918.000000    43.00000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   8237.000000     8237.000000    8237.000000  8237.000000  8237.000000
# mean       0.070147       93.577806     -40.545320     3.608206  5166.589790
# std        1.574685        0.582138       4.623626     1.735931    72.470977
# ...

# %%
df.median(numeric_only=True)
# Out:
# age                 38.000
# duration           179.000
# campaign             2.000
# pdays              999.000
# previous             0.000
# emp.var.rate         1.100
# cons.price.idx      93.444
# cons.conf.idx      -41.800
# euribor3m            4.857
# nr.employed       5191.000
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   32        71         1    999         0           1.4          93.994
#
#    cons.conf.idx  euribor3m  nr.employed
# 0          -36.4      4.857       5228.1

# %%
df.mean(numeric_only=True)
# Out:
# age                 40.116547
# duration           256.007648
# campaign             2.604710
# pdays              962.228724
# previous             0.174335
# emp.var.rate         0.070147
# cons.price.idx      93.577806
# cons.conf.idx      -40.545320
# euribor3m            3.608206
# nr.employed       5166.589790
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# age                10.465328
# duration          259.728737
# campaign            2.915620
# pdays             187.533881
# previous            0.500565
# emp.var.rate        1.574685
# cons.price.idx      0.582138
# cons.conf.idx       4.623626
# euribor3m           1.735931
# nr.employed        72.470977
# dtype: float64

# %%
# Display a random sample of 5 rows
df.sample(5)
# Out:
#       age           job   marital            education default housing loan  \
# 6938   45  entrepreneur  divorced    university.degree      no     yes  yes
# 819    52      services  divorced          high.school      no      no   no
# 3749   27        admin.    single          high.school      no     yes   no
# 7999   46        admin.   married          high.school      no     yes  yes
# 1593   30    technician   married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 6938  telephone   may         thu  ...         2    999         0
# 819   telephone   may         mon  ...         5    999         0
# 3749   cellular   jul         thu  ...         3    999         0
# 7999   cellular   jul         tue  ...         1     13         2
# 1593  telephone   jun         mon  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.sample(20)
# Out:
#       age            job   marital            education  default  housing  \
# 1631   36     management   married    university.degree  unknown       no
# 6988   35     management    single    university.degree       no      yes
# 4981   35         admin.  divorced          high.school       no      yes
# 2003   30  self-employed    single    university.degree       no       no
# 4820   48         admin.  divorced          high.school       no      yes
# 4310   35     technician   married  professional.course       no       no
# 4640   37     technician   married    university.degree       no       no
# 4473   30     technician    single  professional.course       no      yes
# 284    35        unknown   married             basic.9y       no       no
# 3309   31    blue-collar    single             basic.6y       no       no
# 148    36       services    single              unknown       no      yes
# 7164   32     technician    single    university.degree       no       no
# ...

# %%
df.sample(20)
# Out:
#       age           job   marital            education  default housing loan  \
# 732    29  entrepreneur   married             basic.6y       no      no   no
# 508    49   blue-collar   married             basic.4y  unknown      no   no
# 343    26        admin.   married          high.school       no     yes  yes
# 6614   40      services  divorced          high.school       no      no   no
# 1300   40        admin.    single          high.school       no     yes   no
# 646    53      services   married          high.school  unknown      no   no
# 1999   35   blue-collar    single              unknown       no      no   no
# 4305   33    technician    single    university.degree       no     yes   no
# 5196   39      services   married  professional.course       no      no   no
# 6650   28   blue-collar   married             basic.4y       no      no   no
# 5827   36   blue-collar   married             basic.9y       no     yes   no
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#       age          job  marital          education  default housing loan  \
# 0      56     services  married        high.school       no      no  yes
# 1      41  blue-collar  married            unknown  unknown      no   no
# 2      25     services   single        high.school       no     yes   no
# 3      35  blue-collar  married           basic.6y       no     yes   no
# 4      46  blue-collar  married           basic.6y  unknown     yes  yes
# ...   ...          ...      ...                ...      ...     ...  ...
# 8232   41  blue-collar  married           basic.9y       no     yes   no
# 8233   60  blue-collar  married           basic.4y       no     yes   no
# 8234   32       admin.  married  university.degree       no      no   no
# 8235   32       admin.  married  university.degree       no     yes   no
# 8236   36       admin.  married  university.degree       no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# age                 43.180
# duration           253.500
# campaign             1.360
# pdays              999.000
# previous             0.000
# emp.var.rate         1.100
# cons.price.idx      93.994
# cons.conf.idx      -36.400
# euribor3m            4.857
# nr.employed       5191.000
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# age                 39.92000
# duration           331.20000
# campaign             1.90000
# pdays              641.50000
# previous             1.24000
# emp.var.rate        -1.10000
# cons.price.idx      94.68732
# cons.conf.idx      -50.17600
# euribor3m            1.02780
# nr.employed       4963.60000
# dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df['contact']
# Out:
# 0       telephone
# 1       telephone
# 2       telephone
# 3       telephone
# 4       telephone
#           ...
# 8232     cellular
# 8233     cellular
# 8234    telephone
# 8235     cellular
# 8236     cellular
# Name: contact, Length: 8237, dtype: object

# %%
df['month'].describe()
# Out:
# count     8237
# unique      10
# top        may
# freq      2751
# Name: month, dtype: object

# %%
df['contact'].describe()
# Out:
# count         8237
# unique           2
# top       cellular
# freq          5215
# Name: contact, dtype: object

# %%
df['day_of_week'].count()
# Out:
# np.int64(8237)

# %%
df['pdays'].count()
# Out:
# np.int64(8237)

# %%
df['campaign'].mean()
# Out:
# np.float64(2.60471045283477)

# %%
df.loc[10:20,['job', 'marital', 'education', 'default']]
# Out:
#             job  marital            education  default
# 10   technician  married  professional.course  unknown
# 11   technician   single    university.degree       no
# 12  blue-collar  married             basic.9y  unknown
# 13  blue-collar  married             basic.4y  unknown
# 14       admin.  married          high.school  unknown
# 15       admin.  married              unknown  unknown
# 16   unemployed  married             basic.9y       no
# 17  blue-collar  married             basic.6y       no
# 18       admin.  married          high.school       no
# 19   management  married    university.degree       no
# 20       admin.  married              unknown       no

# %%
df.loc[10:29,['job', 'marital', 'education', 'default']]
# Out:
#              job   marital            education  default
# 10    technician   married  professional.course  unknown
# 11    technician    single    university.degree       no
# 12   blue-collar   married             basic.9y  unknown
# 13   blue-collar   married             basic.4y  unknown
# 14        admin.   married          high.school  unknown
# 15        admin.   married              unknown  unknown
# 16    unemployed   married             basic.9y       no
# 17   blue-collar   married             basic.6y       no
# 18        admin.   married          high.school       no
# 19    management   married    university.degree       no
# 20        admin.   married              unknown       no
# 21        admin.   married             basic.6y       no
# 22    technician   married  professional.course  unknown
# 23    management   married    university.degree       no
# 24       unknown  divorced          high.school  unknown
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#       age          job  marital          education  default housing loan  \
# 0      56     services  married        high.school       no      no  yes
# 1      41  blue-collar  married            unknown  unknown      no   no
# 2      25     services   single        high.school       no     yes   no
# 3      35  blue-collar  married           basic.6y       no     yes   no
# 4      46  blue-collar  married           basic.6y  unknown     yes  yes
# ...   ...          ...      ...                ...      ...     ...  ...
# 8232   41  blue-collar  married           basic.9y       no     yes   no
# 8233   60  blue-collar  married           basic.4y       no     yes   no
# 8234   32       admin.  married  university.degree       no      no   no
# 8235   32       admin.  married  university.degree       no     yes   no
# 8236   36       admin.  married  university.degree       no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#       age          job  marital          education  default housing loan  \
# 0      56     services  married        high.school       no      no  yes
# 1      41  blue-collar  married            unknown  unknown      no   no
# 2      25     services   single        high.school       no     yes   no
# 3      35  blue-collar  married           basic.6y       no     yes   no
# 4      46  blue-collar  married           basic.6y  unknown     yes  yes
# ...   ...          ...      ...                ...      ...     ...  ...
# 8232   41  blue-collar  married           basic.9y       no     yes   no
# 8233   60  blue-collar  married           basic.4y       no     yes   no
# 8234   32       admin.  married  university.degree       no      no   no
# 8235   32       admin.  married  university.degree       no     yes   no
# 8236   36       admin.  married  university.degree       no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
df.min()
# Out:
# age                     17
# job                 admin.
# marital           divorced
# education         basic.4y
# default                 no
# housing                 no
# loan                    no
# contact           cellular
# month                  apr
# day_of_week            fri
# duration                 4
# campaign                 1
# pdays                    0
# previous                 0
# poutcome           failure
# emp.var.rate          -3.4
# cons.price.idx      92.201
# cons.conf.idx        -50.8
# euribor3m            0.634
# nr.employed         4963.6
# y                       no
# dtype: object

# %%
df.max()
# Out:
# age                      89
# job                 unknown
# marital             unknown
# education           unknown
# default             unknown
# housing                 yes
# loan                    yes
# contact           telephone
# month                   sep
# day_of_week             wed
# duration               4918
# campaign                 43
# pdays                   999
# previous                  6
# poutcome            success
# emp.var.rate            1.4
# cons.price.idx       94.767
# cons.conf.idx         -26.9
# euribor3m               5.0
# nr.employed          5228.1
# y                       yes
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8237 entries, 0 to 8236
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8237 non-null   int64
#  1   job             8237 non-null   object
#  2   marital         8237 non-null   object
#  3   education       8237 non-null   object
#  4   default         8237 non-null   object
#  5   housing         8237 non-null   object
#  6   loan            8237 non-null   object
#  7   contact         8237 non-null   object
#  8   month           8237 non-null   object
#  9   day_of_week     8237 non-null   object
#  10  duration        8237 non-null   int64
#  11  campaign        8237 non-null   int64
#  12  pdays           8237 non-null   int64
#  13  previous        8237 non-null   int64
#  14  poutcome        8237 non-null   object
#  15  emp.var.rate    8237 non-null   float64
#  16  cons.price.idx  8237 non-null   float64
# ...
