# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
df =pd.read_csv("/content/chess_games.csv")

# %%
df.head()
# Out:
#    game_id  rated  turns victory_status winner time_increment       white_id  \
# 0        1  False     13    Out of Time  White           15+2       bourgris
# 1        2   True     16         Resign  Black           5+10           a-00
# 2        3   True     61           Mate  White           5+10         ischia
# 3        4   True     61           Mate  White           20+0  daniamurashov
# 4        5   True     95           Mate  White           30+3      nik221107
#
#    white_rating      black_id  black_rating  \
# 0          1500          a-00          1191
# 1          1322     skinnerua          1261
# 2          1496          a-00          1500
# 3          1439  adivanov2009          1454
# 4          1523  adivanov2009          1469
#
#                                                moves opening_code  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...          D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...          B00
# ...

# %%
df.head(10)
# Out:
#    game_id  rated  turns victory_status winner time_increment  \
# 0        1  False     13    Out of Time  White           15+2
# 1        2   True     16         Resign  Black           5+10
# 2        3   True     61           Mate  White           5+10
# 3        4   True     61           Mate  White           20+0
# 4        5   True     95           Mate  White           30+3
# 5        6  False      5           Draw   Draw           10+0
# 6        7   True     33         Resign  White           10+0
# 7        8  False      9         Resign  Black          15+30
# 8        9   True     66         Resign  Black           15+0
# 9       10   True    119           Mate  White           10+0
#
#              white_id  white_rating            black_id  black_rating  \
# 0            bourgris          1500                a-00          1191
# 1                a-00          1322           skinnerua          1261
# 2              ischia          1496                a-00          1500
# ...

# %%
df.head(20)
# Out:
#     game_id  rated  turns victory_status winner time_increment  \
# 0         1  False     13    Out of Time  White           15+2
# 1         2   True     16         Resign  Black           5+10
# 2         3   True     61           Mate  White           5+10
# 3         4   True     61           Mate  White           20+0
# 4         5   True     95           Mate  White           30+3
# 5         6  False      5           Draw   Draw           10+0
# 6         7   True     33         Resign  White           10+0
# 7         8  False      9         Resign  Black          15+30
# 8         9   True     66         Resign  Black           15+0
# 9        10   True    119           Mate  White           10+0
# 10       11  False     39           Mate  White          20+60
# 11       12  False     38         Resign  Black          20+60
# 12       13  False     60         Resign  Black           5+40
# 13       14  False     31         Resign  Black            8+0
# ...

# %%
df.tail()
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 20053    20054   True     24         Resign  White          10+10
# 20054    20055   True     82           Mate  Black           10+0
# 20055    20056   True     35           Mate  White           10+0
# 20056    20057   True    109         Resign  White           10+0
# 20057    20058   True     78           Mate  Black           10+0
#
#            white_id  white_rating            black_id  black_rating  \
# 20053       belcolt          1691            jamboger          1220
# 20054      jamboger          1233  farrukhasomiddinov          1196
# 20055      jamboger          1219        schaaksmurf3          1286
# 20056  marcodisogno          1360            jamboger          1227
# 20057      jamboger          1235               ffbob          1339
#
#                                                    moves opening_code  \
# 20053  d4 f5 e3 e6 Nf3 Nf6 Nc3 b6 Be2 Bb7 O-O Be7 Ne5...          A80
# ...

# %%
df.tail(12)
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 20046    20047   True     36           Mate  Black          10+10
# 20047    20048   True     73           Mate  White          10+10
# 20048    20049   True     25         Resign  White          10+10
# 20049    20050   True     43           Mate  White           10+0
# 20050    20051   True      9    Out of Time  White           10+0
# 20051    20052   True     58           Mate  Black          10+10
# 20052    20053   True     37         Resign  White          10+10
# 20053    20054   True     24         Resign  White          10+10
# 20054    20055   True     82           Mate  Black           10+0
# 20055    20056   True     35           Mate  White           10+0
# 20056    20057   True    109         Resign  White           10+0
# 20057    20058   True     78           Mate  Black           10+0
#
#             white_id  white_rating            black_id  black_rating  \
# ...

# %%
df.min(numeric_only=True)
# Out:
# game_id              1
# rated            False
# turns                1
# white_rating       784
# black_rating       789
# opening_moves        1
# dtype: object

# %%
df.max(numeric_only=True)
# Out:
# game_id          20058
# rated             True
# turns              349
# white_rating      2700
# black_rating      2723
# opening_moves       28
# dtype: object

# %%
df.dtypes
# Out:
# game_id               int64
# rated                  bool
# turns                 int64
# victory_status       object
# winner               object
# time_increment       object
# white_id             object
# white_rating          int64
# black_id             object
# black_rating          int64
# moves                object
# opening_code         object
# opening_moves         int64
# opening_fullname     object
# opening_shortname    object
# opening_response     object
# opening_variation    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            20058 non-null  int64
#  1   rated              20058 non-null  bool
#  2   turns              20058 non-null  int64
#  3   victory_status     20058 non-null  object
#  4   winner             20058 non-null  object
#  5   time_increment     20058 non-null  object
#  6   white_id           20058 non-null  object
#  7   white_rating       20058 non-null  int64
#  8   black_id           20058 non-null  object
#  9   black_rating       20058 non-null  int64
#  10  moves              20058 non-null  object
#  11  opening_code       20058 non-null  object
#  12  opening_moves      20058 non-null  int64
#  13  opening_fullname   20058 non-null  object
#  14  opening_shortname  20058 non-null  object
#  15  opening_response   1207 non-null   object
# ...

# %%
df['turns'].dtypes
# Out:
# dtype('int64')

# %%
df['rated'].dtypes
# Out:
# dtype('bool')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=20058, step=1), Index(['game_id', 'rated', 'turns', 'victory_status', 'winner',
#        'time_increment', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_code', 'opening_moves',
#        'opening_fullname', 'opening_shortname', 'opening_response',
#        'opening_variation'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.size)
# Out:
# 340986

# %%
print(df.shape)
# Out:
# (20058, 17)

# %%
print(df.values)
# Out:
# [[1 False 13 ... 'Slav Defense' nan 'Exchange Variation']
#  [2 True 16 ... 'Nimzowitsch Defense' nan 'Kennedy Variation']
#  [3 True 61 ... "King's Pawn Game" nan 'Leonardis Variation']
#  ...
#  [20056 True 35 ... "Queen's Pawn Game" nan 'Mason Attack']
#  [20057 True 109 ... 'Pirc Defense' nan nan]
#  [20058 True 78 ... "Queen's Pawn Game" nan 'Mason Attack']]

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 20058

# %%
print("Number of records:", df.shape[0])
# Out:
# Number of records: 20058

# %%
print("Number of elements:", df.size)
# Out:
# Number of elements: 340986

# %%
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# game_id               int64
# rated                  bool
# turns                 int64
# victory_status       object
# winner               object
# time_increment       object
# white_id             object
# white_rating          int64
# black_id             object
# black_rating          int64
# moves                object
# opening_code         object
# opening_moves         int64
# opening_fullname     object
# opening_shortname    object
# opening_response     object
# opening_variation    object
# dtype: object

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['game_id', 'rated', 'turns', 'victory_status', 'winner',
#        'time_increment', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_code', 'opening_moves',
#        'opening_fullname', 'opening_shortname', 'opening_response',
#        'opening_variation'],
#       dtype='object')

# %%
df.describe()
# Out:
#             game_id         turns  white_rating  black_rating  opening_moves
# count  20058.000000  20058.000000  20058.000000  20058.000000   20058.000000
# mean   10029.500000     60.465999   1596.631868   1588.831987       4.816981
# std     5790.390185     33.570585    291.253376    291.036126       2.797152
# min        1.000000      1.000000    784.000000    789.000000       1.000000
# 25%     5015.250000     37.000000   1398.000000   1391.000000       3.000000
# 50%    10029.500000     55.000000   1567.000000   1562.000000       4.000000
# 75%    15043.750000     79.000000   1793.000000   1784.000000       6.000000
# max    20058.000000    349.000000   2700.000000   2723.000000      28.000000

# %%
df.median(numeric_only=True)
# Out:
# game_id          10029.5
# rated                1.0
# turns               55.0
# white_rating      1567.0
# black_rating      1562.0
# opening_moves        4.0
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# game_id          10029.500000
# rated                0.805414
# turns               60.465999
# white_rating      1596.631868
# black_rating      1588.831987
# opening_moves        4.816981
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#        game_id rated  turns  white_rating  black_rating  opening_moves
# 0            1  True   53.0        1500.0        1500.0            3.0
# 1            2   NaN    NaN           NaN           NaN            NaN
# 2            3   NaN    NaN           NaN           NaN            NaN
# 3            4   NaN    NaN           NaN           NaN            NaN
# 4            5   NaN    NaN           NaN           NaN            NaN
# ...        ...   ...    ...           ...           ...            ...
# 20053    20054   NaN    NaN           NaN           NaN            NaN
# 20054    20055   NaN    NaN           NaN           NaN            NaN
# 20055    20056   NaN    NaN           NaN           NaN            NaN
# 20056    20057   NaN    NaN           NaN           NaN            NaN
# 20057    20058   NaN    NaN           NaN           NaN            NaN
#
# [20058 rows x 6 columns]

# %%
df.std(numeric_only=True)
# Out:
# game_id          5790.390185
# rated               0.395891
# turns              33.570585
# white_rating      291.253376
# black_rating      291.036126
# opening_moves       2.797152
# dtype: float64

# %%
df.sample(5)
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 4433      4434   True     83         Resign  White           10+0
# 15660    15661  False     23           Mate  White           15+0
# 16481    16482   True    200    Out of Time  Black           10+0
# 9172      9173   True     53           Mate  White            4+6
# 14032    14033   True     66           Mate  Black           10+5
#
#           white_id  white_rating             black_id  black_rating  \
# 4433     kerboodle          2331               sorcel          2336
# 15660  julien63000          1500  josephelbouhessaini          1317
# 16481   resiliente          1910            elvispy65          1827
# 9172       alkhane          1190          theking1234           949
# 14032    sdmabunda          1489          yahya-qasem          1604
#
#                                                    moves opening_code  \
# 4433   d4 Nf6 c4 c5 d5 b5 Nd2 Bb7 Qb3 Qb6 e4 bxc4 Qc2...          A57
# ...

# %%
df.sample(20)
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 777        778   True     68         Resign  Black           10+0
# 8982      8983   True     85         Resign  White           10+0
# 7978      7979   True     29         Resign  White           10+0
# 12988    12989   True     81           Mate  White           10+0
# 3762      3763   True     22         Resign  Black          20+15
# 18368    18369   True     39         Resign  White           14+2
# 11281    11282   True    113         Resign  White           15+0
# 18550    18551   True     83         Resign  White            5+8
# 14745    14746   True     41           Mate  White           10+0
# 8464      8465   True     40         Resign  Black           10+0
# 7407      7408   True     24         Resign  White            5+8
# 3332      3333   True     99    Out of Time  White           10+0
# 19427    19428  False     48           Mate  Black           30+0
# ...

# %%
# Remove rows with missing values
df.dropna()
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 29          30   True     66           Mate  Black          10+10
# 33          34  False     21         Resign  Black           15+3
# 98          99   True    113           Draw   Draw           15+0
# 99         100   True     62         Resign  White           15+0
# 107        108   True     91         Resign  White           10+0
# ...        ...    ...    ...            ...    ...            ...
# 19980    19981   True     71         Resign  White          30+30
# 19988    19989   True     57         Resign  White           15+5
# 19989    19990   True     45         Resign  White           10+2
# 19993    19994   True    119           Draw   Draw           15+5
# 20000    20001   True     29         Resign  White            7+2
#
#                 white_id  white_rating         black_id  black_rating  \
# 29     shivangithegenius          1077    chinmaysharma          1148
# ...

# %%
# List all attributes and methods of the DataFrame
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
print("Mean values of the first 50 records:")
print(df.head(50).mean(numeric_only=True))
# Out:
# Mean values of the first 50 records:
# game_id            25.50
# rated               0.38
# turns              41.22
# white_rating     1392.02
# black_rating     1233.24
# opening_moves       5.32
# dtype: float64

# %%
print("Mean values of the last 50 records:")
print(df.tail(50).mean(numeric_only=True))
# Out:
# Mean values of the last 50 records:
# game_id          20033.50
# rated                0.96
# turns               59.02
# white_rating      1606.56
# black_rating      1633.98
# opening_moves        5.68
# dtype: float64

# %%
df.columns
# Out:
# Index(['game_id', 'rated', 'turns', 'victory_status', 'winner',
#        'time_increment', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_code', 'opening_moves',
#        'opening_fullname', 'opening_shortname', 'opening_response',
#        'opening_variation'],
#       dtype='object')

# %%
df['rated']
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 20053     True
# 20054     True
# 20055     True
# 20056     True
# 20057     True
# Name: rated, Length: 20058, dtype: bool

# %%
df['victory_status'].describe()
# Out:
# count      20058
# unique         4
# top       Resign
# freq       11147
# Name: victory_status, dtype: object

# %%
df['winner'].describe()
# Out:
# count     20058
# unique        3
# top       White
# freq      10001
# Name: winner, dtype: object

# %%
df['moves'].count()
# Out:
# np.int64(20058)

# %%
df['opening_shortname'].count()
# Out:
# np.int64(20058)

# %%
df['rated'].mean()
# Out:
# np.float64(0.8054142985342507)

# %%
df['game_id'].mean()
# Out:
# np.float64(10029.5)

# %%
df[10:20]
# Out:
#     game_id  rated  turns victory_status winner time_increment  \
# 10       11  False     39           Mate  White          20+60
# 11       12  False     38         Resign  Black          20+60
# 12       13  False     60         Resign  Black           5+40
# 13       14  False     31         Resign  Black            8+0
# 14       15  False     31           Mate  White          15+15
# 15       16  False     43         Resign  Black          15+15
# 16       17  False     52         Resign  Black          15+15
# 17       18  False     66           Mate  Black          15+16
# 18       19  False    101         Resign  Black          15+15
# 19       20  False     25         Resign  White           11+0
#
#               white_id  white_rating           black_id  black_rating  \
# 10  daniel_likes_chess          1381           anaissac          1272
# 11  daniel_likes_chess          1381          subham777          1867
# ...

# %%
df[10:30]
# Out:
#     game_id  rated  turns victory_status winner time_increment  \
# 10       11  False     39           Mate  White          20+60
# 11       12  False     38         Resign  Black          20+60
# 12       13  False     60         Resign  Black           5+40
# 13       14  False     31         Resign  Black            8+0
# 14       15  False     31           Mate  White          15+15
# 15       16  False     43         Resign  Black          15+15
# 16       17  False     52         Resign  Black          15+15
# 17       18  False     66           Mate  Black          15+16
# 18       19  False    101         Resign  Black          15+15
# 19       20  False     25         Resign  White           11+0
# 20       21  False     14         Resign  Black          15+15
# 21       22  False      3         Resign  White          30+60
# 22       23  False     17         Resign  White           15+5
# 23       24   True     36         Resign  White           10+0
# ...

# %%
df.loc[10:20,['game_id', 'rated', 'turns', 'victory_status']]
# Out:
#     game_id  rated  turns victory_status
# 10       11  False     39           Mate
# 11       12  False     38         Resign
# 12       13  False     60         Resign
# 13       14  False     31         Resign
# 14       15  False     31           Mate
# 15       16  False     43         Resign
# 16       17  False     52         Resign
# 17       18  False     66           Mate
# 18       19  False    101         Resign
# 19       20  False     25         Resign
# 20       21  False     14         Resign

# %%
df.loc[34:40,['opening_shortname', 'opening_response']]
# Out:
#             opening_shortname opening_response
# 34           Sicilian Defense              NaN
# 35  Robatsch (Modern) Defense              NaN
# 36     Blackmar-Diemer Gambit              NaN
# 37                Indian Game              NaN
# 38           Sicilian Defense              NaN
# 39            English Opening              NaN
# 40           Sicilian Defense              NaN

# %%
#MISSING VALUE
df.dropna(how='all')
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 0            1  False     13    Out of Time  White           15+2
# 1            2   True     16         Resign  Black           5+10
# 2            3   True     61           Mate  White           5+10
# 3            4   True     61           Mate  White           20+0
# 4            5   True     95           Mate  White           30+3
# ...        ...    ...    ...            ...    ...            ...
# 20053    20054   True     24         Resign  White          10+10
# 20054    20055   True     82           Mate  Black           10+0
# 20055    20056   True     35           Mate  White           10+0
# 20056    20057   True    109         Resign  White           10+0
# 20057    20058   True     78           Mate  Black           10+0
#
#             white_id  white_rating            black_id  black_rating  \
# 0           bourgris          1500                a-00          1191
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 0            1  False     13    Out of Time  White           15+2
# 1            2   True     16         Resign  Black           5+10
# 2            3   True     61           Mate  White           5+10
# 3            4   True     61           Mate  White           20+0
# 4            5   True     95           Mate  White           30+3
# ...        ...    ...    ...            ...    ...            ...
# 20053    20054   True     24         Resign  White          10+10
# 20054    20055   True     82           Mate  Black           10+0
# 20055    20056   True     35           Mate  White           10+0
# 20056    20057   True    109         Resign  White           10+0
# 20057    20058   True     78           Mate  Black           10+0
#
#             white_id  white_rating            black_id  black_rating  \
# 0           bourgris          1500                a-00          1191
# ...

# %%
df.min(numeric_only=True)
# Out:
# game_id              1
# rated            False
# turns                1
# white_rating       784
# black_rating       789
# opening_moves        1
# dtype: object

# %%
df.max(numeric_only=True)
# Out:
# game_id          20058
# rated             True
# turns              349
# white_rating      2700
# black_rating      2723
# opening_moves       28
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            20058 non-null  int64
#  1   rated              20058 non-null  bool
#  2   turns              20058 non-null  int64
#  3   victory_status     20058 non-null  object
#  4   winner             20058 non-null  object
#  5   time_increment     20058 non-null  object
#  6   white_id           20058 non-null  object
#  7   white_rating       20058 non-null  int64
#  8   black_id           20058 non-null  object
#  9   black_rating       20058 non-null  int64
#  10  moves              20058 non-null  object
#  11  opening_code       20058 non-null  object
#  12  opening_moves      20058 non-null  int64
#  13  opening_fullname   20058 non-null  object
#  14  opening_shortname  20058 non-null  object
#  15  opening_response   1207 non-null   object
# ...
